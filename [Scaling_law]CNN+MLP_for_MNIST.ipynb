# %% [markdown]
# <a href="https://colab.research.google.com/github/hezhonghao/Deep-Learning-Course/blob/main/%5BScaling_law%5DCNN%2BMLP_for_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# This is my implementation of scaling law experiments with a simple one conv layer + one fc, with the goals of observing scaling behaviors between test loss and model/dataset size.
#
# Instruction from Jacob Hilton's advanced DL course:
# https://github.com/jacobhilton/deep_learning_curriculum/blob/master/2-Scaling-Laws.md

# %%
# !kill -9 -1 # restart the kernel

# %% [markdown]
# This is a coding practice to train a simple MLP for MINST. Aug 7th
# Motivation: I've written down numerious code snippets since I took ML/DL courses. But never had I ever executed a complete coding task from the first line to the last line of code.
#
# The code is written in a explicit manner. I hope it particularly helps new learners.

# %%
# !pip install einops
# Out:
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.7.0

# %% [markdown]
# # Set up environment

# %%
# libraries
import torch
import torch.nn as nn
import torchvision.datasets as datasets # Import datasets where you may load MNIST
import torch.optim as optim # Where you get optimization function
import torchvision.transforms as transforms # Where you get those data transformation techniques (including normalization, which is necessary)
from torch.utils.data import DataLoader, Subset
import matplotlib.pyplot as plt
import math

from einops import rearrange,reduce

# %% [markdown]
# # Loading the data

# %%
# Data Normalization
transform = transforms.Compose([
    transforms.ToTensor(), # Transformation happens on GPU
    transforms.Normalize((0.1307,), (0.3081,)), # mean = 0.1307, std = 0.308. This is standard setting for 1 channel grey-scale pictures
])

# %%
# Loading the training data

mnist_trainset = datasets.MNIST(root='./sample_data', train=True, download=True, transform=transform)
train_dataloader = DataLoader(mnist_trainset, batch_size=64, shuffle=True, num_workers=4) # For parallel computation



# prep dataset to understand scaling law for training dataset size
subsets = [Subset(mnist_trainset, torch.randperm(len(mnist_trainset))[:int(len(mnist_trainset) * frac)]) for frac in [1, 1/2, 1/4, 1/8, 1/16, 1/32, 1/64, 1/128, 1/256, 1/512]]

sub_train_dataloaders = []
for subset in subsets:
  sub_train_dataloader = DataLoader(subset, batch_size=64, shuffle=True, num_workers=4, drop_last=True)
  sub_train_dataloaders.append(sub_train_dataloader)

# Loading the test data
mnist_testset = datasets.MNIST(root='./sample_data', train=False, download=True, transform=transform)
test_dataloader = DataLoader(mnist_testset, batch_size=64, shuffle=False, num_workers=4)

'''
Learning:
transform = transforms.Compose([
    transforms.ToTensor(),  # Convert PIL image to tensor
    # Add other necessary transforms here, e.g., normalization
])
This transforms image to tensor. (Notice that transforms.Compose can collect other transformations as well)
Otherwise it would raise the issue that nn.Module can not process "PIL image"
'''
# Out:
# '\nLearning:\ntransform = transforms.Compose([\n    transforms.ToTensor(),  # Convert PIL image to tensor\n    # Add other necessary transforms here, e.g., normalization\n])\nThis transforms image to tensor. (Notice that transforms.Compose can collect other transformations as well)\nOtherwise it would raise the issue that nn.Module can not process "PIL image"\n'

# %% [markdown]
# # Viewing the data (If necessary)
#
#
#
# *   It should include things such as transformations, which was included when data was loaded
#
#
# *   Viewing data is also good to have.

# %%
# Viewing data

# Get one batch of data (images and labels)
data_iter = iter(train_dataloader)
images, labels = next(data_iter)

# Plot the images
fig = plt.figure(figsize=(25,4))  # The size of the figure
for idx in range(20): # Show the first 20 images in the batch
  ax = fig.add_subplot(2,10,idx + 1, xticks=[], yticks=[])
  ax.imshow(images[idx].squeeze(), cmap='gray') # squeeze() is used to remove any unnecessary dimensions, e.g., (1, 28, 28) -> (28, 28)
  ax.set_title(str(labels[idx].item()))
plt.show()

# %% [markdown]
# # CNN + MLP Layer
#
# Updates:
# - Mar 25, 2024 I am adding CNN components into this MLP layer.
#
#
# Structuree:
#
# *   convolution layer
#
# *   Fully connected layer 1
#
# *   Activation function (specific choice does not matter)
#
# *   FC layer 2
#
# Notice
# *   Softmax not included here bc it is implictly included in the Adam optimizer

# %%
class Block(nn.Module):
  def __init__(self, in_channels, out_channels, h, w, output_size):
    super(Block, self).__init__()
    self.conv = nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, stride=1, padding=1)
    self.bn = nn.BatchNorm2d(out_channels)
    self.relu = nn.ReLU()

    self.fc1 = nn.Linear(out_channels * h * w, out_channels)
    self.G = nn.GELU()
    self.fc2 = nn.Linear(out_channels, output_size)

  def forward(self, x):  # x should be input images of size [batch, color_channels, h, w]
    x = self.conv(x)   # output size: [batch, out_channels, h, w]
    x = self.bn(x)
    x = self.relu(x)

    x = x.view(x.size(0),-1)  # output: [batch, dims=out_channels*h*w]
    x = self.fc1(x)
    x = self.G(x)
    prediction = self.fc2(x)
    return prediction

# %% [markdown]
# # Hyper-parameters
#
# Hyper-parameters to be defined:
# - lr
# - choice of loss function
# - choice of optimizer

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Hyperparameters when you adjust training dataset size

# %%
# When you want to execute the model
in_channels = 1  # not RGB, just black-n-white
out_channel = 8 # when # filter is fixed and you look to see scaling law relationship between compute and tese loss.
h=w=28  # image size
output_size = 10 # output size for mnist classfication task

# Define the model  # the default model where we may adjust the training dataset size
model = Block(in_channels, out_channel, h, w, output_size)
print('model:', type(model))

# Choice of Loss function
criterion = nn.CrossEntropyLoss()  # The softmax function is contained in this CEL function.

# Choice of optimizer
optimizer = optim.Adam(model.parameters(), lr=0.0001) # '.parameters()' is a method of nnModule
# Out:
# model: <class '__main__.Block'>

# %% [markdown]
# ## Hyperparameters when you adjust model size

# %%
# When you want to execute the model
in_channels = 1  # not RGB, just black-n-white
out_channels = [8,11,16,23,32,45,64,91,128,181] # 32 filters applied in the conv layer
h=w=28  # image size
output_size = 10 # output size for mnist classfication task

# Define the models. You will have a list of models where each has different number of filters (for CNN)
models = []
for out_c in out_channels:
  model = Block(in_channels, out_c, h, w, output_size)
  models.append(model)
print('models:', type(models))


# learning rate
# lr = 0.0001  # I'll start with a default popular lr. But I may adjust per suggestion "The learning rate will need to vary with model size. Either tune it carefully for each model size, or use the rule of thumb that for Adam, the learning rate should be proportional to the initialization scale, i.e. 1/sqrt(fan_in) for the standard Kaiming He initialization (which is what PyTorch generally uses by default)."
#fan_ins = [math.sqrt(out_channel) for out_channel in out_channels]
# lrs = [lr/(fan_in) for fan_in in fan_ins]  # for Adam, the learning rate should be proportional to the initialization scale, i.e. 1/sqrt(fan_in) for the standard Kaiming He initialization

# Assume 'models' is a list of different model instances with varying sizes
optimizers = []


def calculate_fan_in(model):
  # This example assumes the first layer is a Conv2d, adapt it if it's different
  first_layer = list(model.modules())[1]
  fan_in = first_layer.in_channels * first_layer.kernel_size[0] * first_layer.kernel_size[1]
  return fan_in

for model in models:

    # Assume 'fan_in' is predefined or calculated based on the model's first layer
    fan_in = calculate_fan_in(model)
    lr = 0.0001 / math.sqrt(fan_in)  # Adjust learning rate based on model size
    optimizer = optim.Adam(model.parameters(), lr=lr)
    optimizers.append(optimizer)

# Choice of Loss function
criterion = nn.CrossEntropyLoss()  # The softmax function is contained in this CEL function.
# Choice of optimizer
# optimizer = optim.Adam(model.parameters(), lr=lr) # '.parameters()' is a method of nnModule
# Out:
# models: <class 'list'>

# %% [markdown]
# # Backpropagation and training loop
# You will define a class for backpropation where gradient is calculated
#
# Structure
# *   Iterate through every epoch, then every batch
# *   Flatten your data: 'b c h w -> (b c)(h w)'
# *   Call your model function (forward) to cal predictions (y)
# *   Cost & weights 三部曲：cost, zero grad, gradients, weights
# *   Graph: If you want to plot cost-epoch graph:
#   losses.append(loss.item())  #.item(): from a single-value tensor to a python float
#
#
# Notice:
# *   I didn't use either class or function because we don't need to reuse this.
# *   only use "enumerate" when you need to use the index for batch
# *   Things per batch: cal cost, zero grad, cal gradients, update weights.

# %%
print(type(train_dataloader))
# Out:
# <class 'torch.utils.data.dataloader.DataLoader'>

# %%
# Debug check
import torch

# Check if CUDA is available
if torch.cuda.is_available():
    print(f"CUDA is available. Using GPU: {torch.cuda.get_device_name(0)}")
    device = torch.device("cuda")
else:
    print("CUDA is not available. Using CPU instead.")
    device = torch.device("cpu")

# Later, when defining your model and tensors, you can send them to the chosen device
model = model.to(device)
# And similarly for your tensors
# tensor = tensor.to(device)
# Out:
# CUDA is available. Using GPU: Tesla T4

# %%
# Where time spent on GPU
from torch.profiler import profile, record_function, ProfilerActivity

with profile(activities=[ProfilerActivity.CPU, ProfilerActivity.CUDA], record_shapes=True) as prof:
    with record_function("model_inference"):
        # Your model inference here
        data, target = next(iter(train_dataloader))
        prediction = model(data.to(device))

print(prof.key_averages().table(sort_by="cuda_time_total", row_limit=10))
# Out:
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        10.62%     112.600ms       100.00%        1.060s        1.060s       0.000us         0.00%       1.580ms       1.580ms             1
#                                            aten::linear         0.01%     143.000us         5.33%      56.467ms      28.233ms       0.000us         0.00%       1.049ms     524.500us             2
#                                             aten::addmm         4.33%      45.942ms         5.30%      56.243ms      28.122ms       1.049ms        66.39%       1.049ms     524.500us             2
#                                    volta_sgemm_64x64_tn         0.00%       0.000us         0.00%       0.000us       0.000us       1.037ms        65.63%       1.037ms       1.037ms             1
#                                            aten::conv2d         0.21%       2.251ms        63.70%     675.392ms     675.392ms       0.000us         0.00%     225.000us     225.000us             1
#                                       aten::convolution         0.38%       4.005ms        63.49%     673.141ms     673.141ms       0.000us         0.00%     225.000us     225.000us             1
#                                      aten::_convolution         0.02%     253.000us        63.11%     669.136ms     669.136ms       0.000us         0.00%     225.000us     225.000us             1
#                                        aten::batch_norm         0.00%      10.000us         6.01%      63.702ms      63.702ms       0.000us         0.00%     176.000us     176.000us             1
#                            aten::_batch_norm_impl_index         0.00%      20.000us         6.01%      63.692ms      63.692ms       0.000us         0.00%     176.000us     176.000us             1
#                                  aten::cudnn_batch_norm         1.39%      14.706ms         6.01%      63.672ms      63.672ms     176.000us        11.14%     176.000us     176.000us             1
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 1.060s
# Self CUDA time total: 1.580ms

# %% [markdown]
# # Scaling law relevant models training & evaluating
# Special:
# - One configuration (of training_data size or model size), one model, one test loss (average on epoch)
# - Seperately set up model size (how many CNN kernel layers output_layer do you want) and training data (cut training dataset)

# %%
class traineval(nn.Module):
  def __init__(self, criterion):
    super(traineval, self).__init__()
    self.criterion = criterion

  # Weight initialization  # here you don't need to declar "m". It refers to a layer.
  def weights_init(self, m):
      if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
          torch.nn.init.kaiming_uniform_(m.weight)
          if m.bias is not None:
              torch.nn.init.zeros_(m.bias)

  def train(self, train_data, model, optimizer):  # x is the data input

    # Initialize weights after defining the model architecture
    model.apply(self.weights_init)
    for batch_idx, (data, label) in enumerate(train_data):
      data, label = data.to(device), label.to(device)  # Move data to the same device as the model
      prediction = model(data)
      loss = self.criterion(prediction, label)
      optimizer.zero_grad() # We call zero_grad before each run because you want gradient to be updated for each mini training run (each batch). https://stackoverflow.com/questions/48001598/why-do-we-need-to-call-zero-grad-in-pytorch
      loss.backward() # We call ".backward" to calculate gradients for each training run
      optimizer.step() # We update the model weights according to the gradients
      print(f'The {batch_idx} batch, training loss is {loss.item()}')
      # In the end you get a fully trained model.

  def eval(self, train_data, eval_data, model, optimizer):  # x is the data input

    total_loss = 0
    self.train(train_data,model, optimizer) # model is trained in place.
    model.eval() # Set up the model in eval mode (where things such as dropout and normalization will behave differently.)
    with torch.no_grad():
      for batch_idx, (data, label) in enumerate(eval_data): # Notice that eval_data is a dataloader but of tensor dtype
        data, label = data.to(device), label.to(device)  # Move data to the same device as the model
        logits = model(data)  # returning non-normalized probabilities
        # max_values = reduce(logits, "n c ->n", "max") # Notice that this einops method does not work here bc you are looking for the "labels", which are not returned (but only max values)
        loss = self.criterion(logits, label)  # we use test loss to eval performance because it does not only eval accuracy, but also confidence.
        print(f'The {batch_idx} batch, test loss is {loss.item()}')
        total_loss += loss.item()
      total_loss /= len(eval_data) # len(x) is the size of a batch, assuming x is a dataloader (it is)

    model.train() # flip the training on
    return total_loss

# %% [markdown]
# ## Training models on different datasets (vary in size)

# %%
losses_1 = []
train_eval_process = traineval(criterion)
for idx, dataloader in enumerate(sub_train_dataloaders):
  loss = train_eval_process.eval(dataloader, test_dataloader, model, optimizer)
  print(f'The {idx} model, test loss is {loss}')
  losses_1.append(loss)
plt.plot(losses_1)
plt.title("training loss over time with different dataset size")
plt.xlabel('Data set size (small to big)')
plt.ylabel('Test Loss')
plt.show()
# Out:
# The 0 batch, training loss is 2.7316479682922363
# The 1 batch, training loss is 3.3437530994415283
# The 2 batch, training loss is 3.0911145210266113
# The 3 batch, training loss is 1.9218453168869019
# The 4 batch, training loss is 1.635375738143921
# The 5 batch, training loss is 1.37630033493042
# The 6 batch, training loss is 1.1182911396026611
# The 7 batch, training loss is 0.8820206522941589
# The 8 batch, training loss is 1.0437672138214111
# The 9 batch, training loss is 0.767881453037262
# The 10 batch, training loss is 0.9284400343894958
# The 11 batch, training loss is 0.7084817886352539
# The 12 batch, training loss is 0.8788328766822815
# The 13 batch, training loss is 0.6453952193260193
# The 14 batch, training loss is 0.5097010135650635
# The 15 batch, training loss is 0.557935357093811
# The 16 batch, training loss is 0.8410857915878296
# The 17 batch, training loss is 0.3855070173740387
# The 18 batch, training loss is 0.44863250851631165
# The 19 batch, training loss is 0.29753345251083374
# The 20 batch, training loss is 0.7439915537834167
# The 21 batch, training loss is 0.37747588753700256
# The 22 batch, training loss is 0.49970245361328125
# The 23 batch, training loss is 0.6336674094200134
# The 24 batch, training loss is 0.5938358902931213
# The 25 batch, training loss is 0.5028424263000488
# The 26 batch, training loss is 0.37302032113075256
# The 27 batch, training loss is 0.4051071107387543
# The 28 batch, training loss is 0.3697281777858734
# The 29 batch, training loss is 0.27845391631126404
# The 30 batch, training loss is 0.2958506941795349
# The 31 batch, training loss is 0.3757237493991852
# The 32 batch, training loss is 0.4634988307952881
# The 33 batch, training loss is 0.3463244140148163
# The 34 batch, training loss is 0.454988032579422
# The 35 batch, training loss is 0.4622805714607239
# The 36 batch, training loss is 0.2595139145851135
# The 37 batch, training loss is 0.33475401997566223
# The 38 batch, training loss is 0.5888481736183167
# The 39 batch, training loss is 0.4294576942920685
# The 40 batch, training loss is 0.31952783465385437
# The 41 batch, training loss is 0.2804557681083679
# The 42 batch, training loss is 0.38743826746940613
# The 43 batch, training loss is 0.45999273657798767
# The 44 batch, training loss is 0.4366215169429779
# The 45 batch, training loss is 0.2832578420639038
# The 46 batch, training loss is 0.08017022162675858
# The 47 batch, training loss is 0.6256859302520752
# The 48 batch, training loss is 0.41429612040519714
# The 49 batch, training loss is 0.4521196484565735
# The 50 batch, training loss is 0.40206727385520935
# The 51 batch, training loss is 0.17208513617515564
# The 52 batch, training loss is 0.35253793001174927
# The 53 batch, training loss is 0.19067834317684174
# The 54 batch, training loss is 0.3178701102733612
# The 55 batch, training loss is 0.3190799951553345
# The 56 batch, training loss is 0.6197962760925293
# The 57 batch, training loss is 0.3738114535808563
# The 58 batch, training loss is 0.23782500624656677
# The 59 batch, training loss is 0.23461441695690155
# The 60 batch, training loss is 0.5664576292037964
# The 61 batch, training loss is 0.12684710323810577
# The 62 batch, training loss is 0.47169873118400574
# The 63 batch, training loss is 0.32675448060035706
# The 64 batch, training loss is 0.4768853485584259
# The 65 batch, training loss is 0.34859901666641235
# The 66 batch, training loss is 0.26305654644966125
# The 67 batch, training loss is 0.2313767969608307
# The 68 batch, training loss is 0.2795869708061218
# The 69 batch, training loss is 0.30802121758461
# The 70 batch, training loss is 0.19962185621261597
# The 71 batch, training loss is 0.42233726382255554
# The 72 batch, training loss is 0.25890377163887024
# The 73 batch, training loss is 0.5220723748207092
# The 74 batch, training loss is 0.3179455101490021
# The 75 batch, training loss is 0.3500227630138397
# The 76 batch, training loss is 0.4116598665714264
# The 77 batch, training loss is 0.375213086605072
# The 78 batch, training loss is 0.24528509378433228
# The 79 batch, training loss is 0.3267328441143036
# The 80 batch, training loss is 0.31482934951782227
# The 81 batch, training loss is 0.23719140887260437
# The 82 batch, training loss is 0.2627330422401428
# The 83 batch, training loss is 0.22994105517864227
# The 84 batch, training loss is 0.214811772108078
# The 85 batch, training loss is 0.1323312371969223
# The 86 batch, training loss is 0.4818848669528961
# The 87 batch, training loss is 0.3568207919597626
# The 88 batch, training loss is 0.219725102186203
# The 89 batch, training loss is 0.28180113434791565
# The 90 batch, training loss is 0.3483351767063141
# The 91 batch, training loss is 0.2540978491306305
# The 92 batch, training loss is 0.22345119714736938
# The 93 batch, training loss is 0.3577245771884918
# The 94 batch, training loss is 0.36870482563972473
# The 95 batch, training loss is 0.3237129747867584
# The 96 batch, training loss is 0.2175416201353073
# The 97 batch, training loss is 0.30036380887031555
# The 98 batch, training loss is 0.13076423108577728
# The 99 batch, training loss is 0.17403975129127502
# The 100 batch, training loss is 0.25236737728118896
# The 101 batch, training loss is 0.18508672714233398
# The 102 batch, training loss is 0.11203613877296448
# The 103 batch, training loss is 0.22507791221141815
# The 104 batch, training loss is 0.26186037063598633
# The 105 batch, training loss is 0.2718908488750458
# The 106 batch, training loss is 0.3234388828277588
# The 107 batch, training loss is 0.3772265911102295
# The 108 batch, training loss is 0.26142051815986633
# The 109 batch, training loss is 0.2915603816509247
# The 110 batch, training loss is 0.34991568326950073
# The 111 batch, training loss is 0.6501072645187378
# The 112 batch, training loss is 0.5325345993041992
# The 113 batch, training loss is 0.2706446647644043
# The 114 batch, training loss is 0.19432255625724792
# The 115 batch, training loss is 0.2459605634212494
# The 116 batch, training loss is 0.2721538543701172
# The 117 batch, training loss is 0.2367653101682663
# The 118 batch, training loss is 0.319706529378891
# The 119 batch, training loss is 0.3632411062717438
# The 120 batch, training loss is 0.1222829520702362
# The 121 batch, training loss is 0.14072193205356598
# The 122 batch, training loss is 0.2647237181663513
# The 123 batch, training loss is 0.5435819625854492
# The 124 batch, training loss is 0.23613721132278442
# The 125 batch, training loss is 0.19107501208782196
# The 126 batch, training loss is 0.17198842763900757
# The 127 batch, training loss is 0.16089999675750732
# The 128 batch, training loss is 0.13796985149383545
# The 129 batch, training loss is 0.29791542887687683
# The 130 batch, training loss is 0.24546049535274506
# The 131 batch, training loss is 0.24631960690021515
# The 132 batch, training loss is 0.20799671113491058
# The 133 batch, training loss is 0.5459742546081543
# The 134 batch, training loss is 0.44616854190826416
# The 135 batch, training loss is 0.267643541097641
# The 136 batch, training loss is 0.28122493624687195
# The 137 batch, training loss is 0.27940458059310913
# The 138 batch, training loss is 0.31590718030929565
# The 139 batch, training loss is 0.18346638977527618
# The 140 batch, training loss is 0.20117640495300293
# The 141 batch, training loss is 0.26605352759361267
# The 142 batch, training loss is 0.4939878284931183
# The 143 batch, training loss is 0.24568329751491547
# The 144 batch, training loss is 0.2637447416782379
# The 145 batch, training loss is 0.1987270712852478
# The 146 batch, training loss is 0.18535929918289185
# The 147 batch, training loss is 0.35477414727211
# The 148 batch, training loss is 0.21776294708251953
# The 149 batch, training loss is 0.5743885040283203
# The 150 batch, training loss is 0.262177437543869
# The 151 batch, training loss is 0.1733819991350174
# The 152 batch, training loss is 0.2571907937526703
# The 153 batch, training loss is 0.3435802757740021
# The 154 batch, training loss is 0.19402901828289032
# The 155 batch, training loss is 0.20418775081634521
# The 156 batch, training loss is 0.3575364351272583
# The 157 batch, training loss is 0.24687601625919342
# The 158 batch, training loss is 0.2026812583208084
# The 159 batch, training loss is 0.3738000988960266
# The 160 batch, training loss is 0.16535842418670654
# The 161 batch, training loss is 0.2715098261833191
# The 162 batch, training loss is 0.2479294240474701
# The 163 batch, training loss is 0.21176394820213318
# The 164 batch, training loss is 0.21728524565696716
# The 165 batch, training loss is 0.5096531510353088
# The 166 batch, training loss is 0.22484491765499115
# The 167 batch, training loss is 0.18894517421722412
# The 168 batch, training loss is 0.10635950416326523
# The 169 batch, training loss is 0.3695615231990814
# The 170 batch, training loss is 0.5360794067382812
# The 171 batch, training loss is 0.626940131187439
# The 172 batch, training loss is 0.3432862460613251
# The 173 batch, training loss is 0.252280592918396
# The 174 batch, training loss is 0.16954025626182556
# The 175 batch, training loss is 0.30116114020347595
# The 176 batch, training loss is 0.08779486268758774
# The 177 batch, training loss is 0.3627205491065979
# The 178 batch, training loss is 0.17180170118808746
# The 179 batch, training loss is 0.2394304722547531
# The 180 batch, training loss is 0.3237958550453186
# The 181 batch, training loss is 0.28682130575180054
# The 182 batch, training loss is 0.10578563064336777
# The 183 batch, training loss is 0.20988638699054718
# The 184 batch, training loss is 0.041545938700437546
# The 185 batch, training loss is 0.14894582331180573
# The 186 batch, training loss is 0.32780683040618896
# The 187 batch, training loss is 0.19756081700325012
# The 188 batch, training loss is 0.27207592129707336
# The 189 batch, training loss is 0.16971461474895477
# The 190 batch, training loss is 0.20295313000679016
# The 191 batch, training loss is 0.39114516973495483
# The 192 batch, training loss is 0.2638341188430786
# The 193 batch, training loss is 0.2656481862068176
# The 194 batch, training loss is 0.2971957325935364
# The 195 batch, training loss is 0.11266961693763733
# The 196 batch, training loss is 0.2214539647102356
# The 197 batch, training loss is 0.27812308073043823
# The 198 batch, training loss is 0.1667127162218094
# The 199 batch, training loss is 0.13105440139770508
# The 200 batch, training loss is 0.23476959764957428
# The 201 batch, training loss is 0.3207695782184601
# The 202 batch, training loss is 0.1676427572965622
# The 203 batch, training loss is 0.16392533481121063
# The 204 batch, training loss is 0.07394243776798248
# The 205 batch, training loss is 0.22985690832138062
# The 206 batch, training loss is 0.30123987793922424
# The 207 batch, training loss is 0.10793346166610718
# The 208 batch, training loss is 0.10157735645771027
# The 209 batch, training loss is 0.22820031642913818
# The 210 batch, training loss is 0.24266915023326874
# The 211 batch, training loss is 0.25910618901252747
# The 212 batch, training loss is 0.1435965746641159
# The 213 batch, training loss is 0.21056756377220154
# The 214 batch, training loss is 0.34276092052459717
# The 215 batch, training loss is 0.1524086892604828
# The 216 batch, training loss is 0.18897585570812225
# The 217 batch, training loss is 0.09475728869438171
# The 218 batch, training loss is 0.21222350001335144
# The 219 batch, training loss is 0.30851370096206665
# The 220 batch, training loss is 0.18648965656757355
# The 221 batch, training loss is 0.2985868453979492
# The 222 batch, training loss is 0.26162511110305786
# The 223 batch, training loss is 0.2578974962234497
# The 224 batch, training loss is 0.20234784483909607
# The 225 batch, training loss is 0.25526222586631775
# The 226 batch, training loss is 0.26195934414863586
# The 227 batch, training loss is 0.297376811504364
# The 228 batch, training loss is 0.19492684304714203
# The 229 batch, training loss is 0.13801530003547668
# The 230 batch, training loss is 0.28397658467292786
# The 231 batch, training loss is 0.20693404972553253
# The 232 batch, training loss is 0.16852489113807678
# The 233 batch, training loss is 0.17274177074432373
# The 234 batch, training loss is 0.1527734100818634
# The 235 batch, training loss is 0.3685321509838104
# The 236 batch, training loss is 0.2470756471157074
# The 237 batch, training loss is 0.16102978587150574
# The 238 batch, training loss is 0.15339289605617523
# The 239 batch, training loss is 0.1441633254289627
# The 240 batch, training loss is 0.2400147169828415
# The 241 batch, training loss is 0.18775472044944763
# The 242 batch, training loss is 0.2476581484079361
# The 243 batch, training loss is 0.2688295245170593
# The 244 batch, training loss is 0.1525322049856186
# The 245 batch, training loss is 0.27564820647239685
# The 246 batch, training loss is 0.21457569301128387
# The 247 batch, training loss is 0.2481752634048462
# The 248 batch, training loss is 0.2787754237651825
# The 249 batch, training loss is 0.10285675525665283
# The 250 batch, training loss is 0.3695468008518219
# The 251 batch, training loss is 0.1746622622013092
# The 252 batch, training loss is 0.16701221466064453
# The 253 batch, training loss is 0.15690088272094727
# The 254 batch, training loss is 0.1126118153333664
# The 255 batch, training loss is 0.27405276894569397
# The 256 batch, training loss is 0.0862366110086441
# The 257 batch, training loss is 0.24939393997192383
# The 258 batch, training loss is 0.15134933590888977
# The 259 batch, training loss is 0.26818302273750305
# The 260 batch, training loss is 0.1064334288239479
# The 261 batch, training loss is 0.16112424433231354
# The 262 batch, training loss is 0.17134380340576172
# The 263 batch, training loss is 0.17676618695259094
# The 264 batch, training loss is 0.05575227737426758
# The 265 batch, training loss is 0.317890465259552
# The 266 batch, training loss is 0.21989980340003967
# The 267 batch, training loss is 0.21661363542079926
# The 268 batch, training loss is 0.05131100118160248
# The 269 batch, training loss is 0.23926480114459991
# The 270 batch, training loss is 0.12386815994977951
# The 271 batch, training loss is 0.17401795089244843
# The 272 batch, training loss is 0.38291165232658386
# The 273 batch, training loss is 0.16850455105304718
# The 274 batch, training loss is 0.1889440417289734
# The 275 batch, training loss is 0.24659249186515808
# The 276 batch, training loss is 0.15316863358020782
# The 277 batch, training loss is 0.02797834202647209
# The 278 batch, training loss is 0.16137343645095825
# The 279 batch, training loss is 0.08419257402420044
# The 280 batch, training loss is 0.06910451501607895
# The 281 batch, training loss is 0.12659814953804016
# The 282 batch, training loss is 0.17461876571178436
# The 283 batch, training loss is 0.1963295042514801
# The 284 batch, training loss is 0.05181579664349556
# The 285 batch, training loss is 0.14718976616859436
# The 286 batch, training loss is 0.3063581585884094
# The 287 batch, training loss is 0.3518066704273224
# The 288 batch, training loss is 0.1132352203130722
# The 289 batch, training loss is 0.18555760383605957
# The 290 batch, training loss is 0.31815028190612793
# The 291 batch, training loss is 0.09347885847091675
# The 292 batch, training loss is 0.3258075416088104
# The 293 batch, training loss is 0.033275362104177475
# The 294 batch, training loss is 0.15447655320167542
# The 295 batch, training loss is 0.1285695880651474
# The 296 batch, training loss is 0.1255740225315094
# The 297 batch, training loss is 0.2298012375831604
# The 298 batch, training loss is 0.23308813571929932
# The 299 batch, training loss is 0.16460534930229187
# The 300 batch, training loss is 0.2985193431377411
# The 301 batch, training loss is 0.09475597739219666
# The 302 batch, training loss is 0.21582376956939697
# The 303 batch, training loss is 0.17180247604846954
# The 304 batch, training loss is 0.17831210792064667
# The 305 batch, training loss is 0.422909140586853
# The 306 batch, training loss is 0.14709806442260742
# The 307 batch, training loss is 0.16269409656524658
# The 308 batch, training loss is 0.24622555077075958
# The 309 batch, training loss is 0.1803312450647354
# The 310 batch, training loss is 0.18341222405433655
# The 311 batch, training loss is 0.27199408411979675
# The 312 batch, training loss is 0.11486256122589111
# The 313 batch, training loss is 0.11637148261070251
# The 314 batch, training loss is 0.2744746804237366
# The 315 batch, training loss is 0.2383062094449997
# The 316 batch, training loss is 0.14547163248062134
# The 317 batch, training loss is 0.026480568572878838
# The 318 batch, training loss is 0.08502257615327835
# The 319 batch, training loss is 0.13442596793174744
# The 320 batch, training loss is 0.09676942974328995
# The 321 batch, training loss is 0.23918037116527557
# The 322 batch, training loss is 0.17881552875041962
# The 323 batch, training loss is 0.268477201461792
# The 324 batch, training loss is 0.06035860627889633
# The 325 batch, training loss is 0.1776823103427887
# The 326 batch, training loss is 0.20740821957588196
# The 327 batch, training loss is 0.14726276695728302
# The 328 batch, training loss is 0.13678433001041412
# The 329 batch, training loss is 0.06379479169845581
# The 330 batch, training loss is 0.20636768639087677
# The 331 batch, training loss is 0.19837069511413574
# The 332 batch, training loss is 0.22322411835193634
# The 333 batch, training loss is 0.10271352529525757
# The 334 batch, training loss is 0.160692036151886
# The 335 batch, training loss is 0.32116255164146423
# The 336 batch, training loss is 0.09763652831315994
# The 337 batch, training loss is 0.1848011165857315
# The 338 batch, training loss is 0.0707903504371643
# The 339 batch, training loss is 0.22285354137420654
# The 340 batch, training loss is 0.147225484251976
# The 341 batch, training loss is 0.12340247631072998
# The 342 batch, training loss is 0.1429634690284729
# The 343 batch, training loss is 0.2881978154182434
# The 344 batch, training loss is 0.16781476140022278
# The 345 batch, training loss is 0.23118580877780914
# The 346 batch, training loss is 0.1825253963470459
# The 347 batch, training loss is 0.12093927711248398
# The 348 batch, training loss is 0.037257567048072815
# The 349 batch, training loss is 0.41001057624816895
# The 350 batch, training loss is 0.17605066299438477
# The 351 batch, training loss is 0.3423212468624115
# The 352 batch, training loss is 0.2808178663253784
# The 353 batch, training loss is 0.09526961296796799
# The 354 batch, training loss is 0.1846875250339508
# The 355 batch, training loss is 0.3796549439430237
# The 356 batch, training loss is 0.2117980271577835
# The 357 batch, training loss is 0.21958698332309723
# The 358 batch, training loss is 0.19666293263435364
# The 359 batch, training loss is 0.22516921162605286
# The 360 batch, training loss is 0.24402938783168793
# The 361 batch, training loss is 0.10239210724830627
# The 362 batch, training loss is 0.13921499252319336
# The 363 batch, training loss is 0.24977263808250427
# The 364 batch, training loss is 0.13098032772541046
# The 365 batch, training loss is 0.27308982610702515
# The 366 batch, training loss is 0.17942897975444794
# The 367 batch, training loss is 0.1697939783334732
# The 368 batch, training loss is 0.17151260375976562
# The 369 batch, training loss is 0.07086033374071121
# The 370 batch, training loss is 0.07923147082328796
# The 371 batch, training loss is 0.350795716047287
# The 372 batch, training loss is 0.19772914052009583
# The 373 batch, training loss is 0.19607123732566833
# The 374 batch, training loss is 0.2264217883348465
# The 375 batch, training loss is 0.09588003158569336
# The 376 batch, training loss is 0.15084101259708405
# The 377 batch, training loss is 0.16655626893043518
# The 378 batch, training loss is 0.16966263949871063
# The 379 batch, training loss is 0.22305117547512054
# The 380 batch, training loss is 0.21032407879829407
# The 381 batch, training loss is 0.15777145326137543
# The 382 batch, training loss is 0.19607801735401154
# The 383 batch, training loss is 0.22310598194599152
# The 384 batch, training loss is 0.195522278547287
# The 385 batch, training loss is 0.04194639250636101
# The 386 batch, training loss is 0.10874253511428833
# The 387 batch, training loss is 0.3479316234588623
# The 388 batch, training loss is 0.1506100296974182
# The 389 batch, training loss is 0.0323580801486969
# The 390 batch, training loss is 0.25325846672058105
# The 391 batch, training loss is 0.14125077426433563
# The 392 batch, training loss is 0.11798350512981415
# The 393 batch, training loss is 0.0925840213894844
# The 394 batch, training loss is 0.1921379119157791
# The 395 batch, training loss is 0.1630571037530899
# The 396 batch, training loss is 0.06646590679883957
# The 397 batch, training loss is 0.22617053985595703
# The 398 batch, training loss is 0.08445806056261063
# The 399 batch, training loss is 0.07787897437810898
# The 400 batch, training loss is 0.05210232734680176
# The 401 batch, training loss is 0.3307975232601166
# The 402 batch, training loss is 0.055469807237386703
# The 403 batch, training loss is 0.2519206702709198
# The 404 batch, training loss is 0.24256736040115356
# The 405 batch, training loss is 0.2223081737756729
# The 406 batch, training loss is 0.130815789103508
# The 407 batch, training loss is 0.11980611085891724
# The 408 batch, training loss is 0.09302942454814911
# The 409 batch, training loss is 0.15412363409996033
# The 410 batch, training loss is 0.13839294016361237
# The 411 batch, training loss is 0.12864436209201813
# The 412 batch, training loss is 0.2000678926706314
# The 413 batch, training loss is 0.08207188546657562
# The 414 batch, training loss is 0.15945392847061157
# The 415 batch, training loss is 0.12039365619421005
# The 416 batch, training loss is 0.2580627501010895
# The 417 batch, training loss is 0.1906857043504715
# The 418 batch, training loss is 0.03664878010749817
# The 419 batch, training loss is 0.041656848043203354
# The 420 batch, training loss is 0.13063780963420868
# The 421 batch, training loss is 0.1212463453412056
# The 422 batch, training loss is 0.20193946361541748
# The 423 batch, training loss is 0.053345032036304474
# The 424 batch, training loss is 0.031173482537269592
# The 425 batch, training loss is 0.05353729426860809
# The 426 batch, training loss is 0.16799524426460266
# The 427 batch, training loss is 0.1502387672662735
# The 428 batch, training loss is 0.15764914453029633
# The 429 batch, training loss is 0.23323209583759308
# The 430 batch, training loss is 0.1992339938879013
# The 431 batch, training loss is 0.046867355704307556
# The 432 batch, training loss is 0.1386147290468216
# The 433 batch, training loss is 0.08761932700872421
# The 434 batch, training loss is 0.24340032041072845
# The 435 batch, training loss is 0.25606459379196167
# The 436 batch, training loss is 0.10637379437685013
# The 437 batch, training loss is 0.1373809576034546
# The 438 batch, training loss is 0.15191087126731873
# The 439 batch, training loss is 0.15493424236774445
# The 440 batch, training loss is 0.18111489713191986
# The 441 batch, training loss is 0.309930682182312
# The 442 batch, training loss is 0.08515053987503052
# The 443 batch, training loss is 0.14879107475280762
# The 444 batch, training loss is 0.15805713832378387
# The 445 batch, training loss is 0.052094075828790665
# The 446 batch, training loss is 0.10890066623687744
# The 447 batch, training loss is 0.18865251541137695
# The 448 batch, training loss is 0.1177900955080986
# The 449 batch, training loss is 0.3021584153175354
# The 450 batch, training loss is 0.11049436777830124
# The 451 batch, training loss is 0.1769670844078064
# The 452 batch, training loss is 0.19210085272789001
# The 453 batch, training loss is 0.17516003549098969
# The 454 batch, training loss is 0.09588184952735901
# The 455 batch, training loss is 0.1849382370710373
# The 456 batch, training loss is 0.2315504550933838
# The 457 batch, training loss is 0.15786325931549072
# The 458 batch, training loss is 0.14116868376731873
# The 459 batch, training loss is 0.14159831404685974
# The 460 batch, training loss is 0.21367524564266205
# The 461 batch, training loss is 0.1349467784166336
# The 462 batch, training loss is 0.1287945806980133
# The 463 batch, training loss is 0.11404553800821304
# The 464 batch, training loss is 0.14315074682235718
# The 465 batch, training loss is 0.24358364939689636
# The 466 batch, training loss is 0.4229382276535034
# The 467 batch, training loss is 0.08657688647508621
# The 468 batch, training loss is 0.15726101398468018
# The 469 batch, training loss is 0.3356216847896576
# The 470 batch, training loss is 0.19339226186275482
# The 471 batch, training loss is 0.3359847366809845
# The 472 batch, training loss is 0.0758022591471672
# The 473 batch, training loss is 0.12889379262924194
# The 474 batch, training loss is 0.10805066674947739
# The 475 batch, training loss is 0.08607856184244156
# The 476 batch, training loss is 0.08984311670064926
# The 477 batch, training loss is 0.03841250762343407
# The 478 batch, training loss is 0.2650579810142517
# The 479 batch, training loss is 0.20616501569747925
# The 480 batch, training loss is 0.07708042114973068
# The 481 batch, training loss is 0.2966184616088867
# The 482 batch, training loss is 0.1215280219912529
# The 483 batch, training loss is 0.17846998572349548
# The 484 batch, training loss is 0.11703400313854218
# The 485 batch, training loss is 0.07272101193666458
# The 486 batch, training loss is 0.1367330253124237
# The 487 batch, training loss is 0.1113201379776001
# The 488 batch, training loss is 0.19562308490276337
# The 489 batch, training loss is 0.13291171193122864
# The 490 batch, training loss is 0.20475637912750244
# The 491 batch, training loss is 0.3774257302284241
# The 492 batch, training loss is 0.0687580481171608
# The 493 batch, training loss is 0.09450557082891464
# The 494 batch, training loss is 0.05453522503376007
# The 495 batch, training loss is 0.18291358649730682
# The 496 batch, training loss is 0.19829191267490387
# The 497 batch, training loss is 0.17366614937782288
# The 498 batch, training loss is 0.11492627114057541
# The 499 batch, training loss is 0.11100465059280396
# The 500 batch, training loss is 0.12073978781700134
# The 501 batch, training loss is 0.13626688718795776
# The 502 batch, training loss is 0.07777266204357147
# The 503 batch, training loss is 0.16896285116672516
# The 504 batch, training loss is 0.10385993868112564
# The 505 batch, training loss is 0.2664209306240082
# The 506 batch, training loss is 0.3483184576034546
# The 507 batch, training loss is 0.17364563047885895
# The 508 batch, training loss is 0.15319795906543732
# The 509 batch, training loss is 0.419497549533844
# The 510 batch, training loss is 0.07574410736560822
# The 511 batch, training loss is 0.08856093883514404
# The 512 batch, training loss is 0.09613299369812012
# The 513 batch, training loss is 0.16131792962551117
# The 514 batch, training loss is 0.2834513187408447
# The 515 batch, training loss is 0.1278962939977646
# The 516 batch, training loss is 0.16600868105888367
# The 517 batch, training loss is 0.11003155261278152
# The 518 batch, training loss is 0.23692572116851807
# The 519 batch, training loss is 0.059248410165309906
# The 520 batch, training loss is 0.22513557970523834
# The 521 batch, training loss is 0.06327807903289795
# The 522 batch, training loss is 0.09638659656047821
# The 523 batch, training loss is 0.30962225794792175
# The 524 batch, training loss is 0.13724853098392487
# The 525 batch, training loss is 0.14991408586502075
# The 526 batch, training loss is 0.07989642024040222
# The 527 batch, training loss is 0.1241292804479599
# The 528 batch, training loss is 0.23148080706596375
# The 529 batch, training loss is 0.113155797123909
# The 530 batch, training loss is 0.12719257175922394
# The 531 batch, training loss is 0.20753835141658783
# The 532 batch, training loss is 0.14120995998382568
# The 533 batch, training loss is 0.10377196222543716
# The 534 batch, training loss is 0.05629398301243782
# The 535 batch, training loss is 0.27801987528800964
# The 536 batch, training loss is 0.21908468008041382
# The 537 batch, training loss is 0.24694426357746124
# The 538 batch, training loss is 0.137041836977005
# The 539 batch, training loss is 0.0893256887793541
# The 540 batch, training loss is 0.2815757393836975
# The 541 batch, training loss is 0.1710558831691742
# The 542 batch, training loss is 0.04371729493141174
# The 543 batch, training loss is 0.13266940414905548
# The 544 batch, training loss is 0.10735388100147247
# The 545 batch, training loss is 0.10360678285360336
# The 546 batch, training loss is 0.3143683671951294
# The 547 batch, training loss is 0.1578356772661209
# The 548 batch, training loss is 0.09439950436353683
# The 549 batch, training loss is 0.23868587613105774
# The 550 batch, training loss is 0.07618626207113266
# The 551 batch, training loss is 0.11985912919044495
# The 552 batch, training loss is 0.212228462100029
# The 553 batch, training loss is 0.0317414328455925
# The 554 batch, training loss is 0.28865447640419006
# The 555 batch, training loss is 0.08354764431715012
# The 556 batch, training loss is 0.22096092998981476
# The 557 batch, training loss is 0.19565780460834503
# The 558 batch, training loss is 0.1608729064464569
# The 559 batch, training loss is 0.18028932809829712
# The 560 batch, training loss is 0.04821034148335457
# The 561 batch, training loss is 0.14493167400360107
# The 562 batch, training loss is 0.07478643208742142
# The 563 batch, training loss is 0.154884472489357
# The 564 batch, training loss is 0.2605292797088623
# The 565 batch, training loss is 0.25618526339530945
# The 566 batch, training loss is 0.09434973448514938
# The 567 batch, training loss is 0.0401814766228199
# The 568 batch, training loss is 0.07427661865949631
# The 569 batch, training loss is 0.06173329055309296
# The 570 batch, training loss is 0.22682978212833405
# The 571 batch, training loss is 0.045531172305345535
# The 572 batch, training loss is 0.07050231844186783
# The 573 batch, training loss is 0.13423104584217072
# The 574 batch, training loss is 0.2770020365715027
# The 575 batch, training loss is 0.22675089538097382
# The 576 batch, training loss is 0.10017065703868866
# The 577 batch, training loss is 0.16592317819595337
# The 578 batch, training loss is 0.12133821845054626
# The 579 batch, training loss is 0.18053779006004333
# The 580 batch, training loss is 0.18664930760860443
# The 581 batch, training loss is 0.260047972202301
# The 582 batch, training loss is 0.1490468978881836
# The 583 batch, training loss is 0.13115458190441132
# The 584 batch, training loss is 0.04673535004258156
# The 585 batch, training loss is 0.02594045177102089
# The 586 batch, training loss is 0.0593947097659111
# The 587 batch, training loss is 0.32707005739212036
# The 588 batch, training loss is 0.15126459300518036
# The 589 batch, training loss is 0.04372962564229965
# The 590 batch, training loss is 0.09555059671401978
# The 591 batch, training loss is 0.15682008862495422
# The 592 batch, training loss is 0.08863839507102966
# The 593 batch, training loss is 0.09509577602148056
# The 594 batch, training loss is 0.0733356773853302
# The 595 batch, training loss is 0.05142436921596527
# The 596 batch, training loss is 0.22052301466464996
# The 597 batch, training loss is 0.1464672088623047
# The 598 batch, training loss is 0.09607977420091629
# The 599 batch, training loss is 0.060822900384664536
# The 600 batch, training loss is 0.1212514117360115
# The 601 batch, training loss is 0.3848356604576111
# The 602 batch, training loss is 0.09996853768825531
# The 603 batch, training loss is 0.22604985535144806
# The 604 batch, training loss is 0.14664365351200104
# The 605 batch, training loss is 0.0788077637553215
# The 606 batch, training loss is 0.1747736930847168
# The 607 batch, training loss is 0.05484826862812042
# The 608 batch, training loss is 0.08623069524765015
# The 609 batch, training loss is 0.10032738000154495
# The 610 batch, training loss is 0.2572927474975586
# The 611 batch, training loss is 0.5212327241897583
# The 612 batch, training loss is 0.2761826813220978
# The 613 batch, training loss is 0.10491625219583511
# The 614 batch, training loss is 0.28915533423423767
# The 615 batch, training loss is 0.428733229637146
# The 616 batch, training loss is 0.2934103012084961
# The 617 batch, training loss is 0.08307855576276779
# The 618 batch, training loss is 0.1924407184123993
# The 619 batch, training loss is 0.17808014154434204
# The 620 batch, training loss is 0.18304039537906647
# The 621 batch, training loss is 0.15171314775943756
# The 622 batch, training loss is 0.10946846008300781
# The 623 batch, training loss is 0.09827113151550293
# The 624 batch, training loss is 0.12181458622217178
# The 625 batch, training loss is 0.0720847100019455
# The 626 batch, training loss is 0.060806818306446075
# The 627 batch, training loss is 0.17785537242889404
# The 628 batch, training loss is 0.13440431654453278
# The 629 batch, training loss is 0.08967374265193939
# The 630 batch, training loss is 0.28644058108329773
# The 631 batch, training loss is 0.22999493777751923
# The 632 batch, training loss is 0.14039966464042664
# The 633 batch, training loss is 0.02443253993988037
# The 634 batch, training loss is 0.16287581622600555
# The 635 batch, training loss is 0.0419311486184597
# The 636 batch, training loss is 0.1122024655342102
# The 637 batch, training loss is 0.246022030711174
# The 638 batch, training loss is 0.31572502851486206
# The 639 batch, training loss is 0.05635357275605202
# The 640 batch, training loss is 0.08571351319551468
# The 641 batch, training loss is 0.14057812094688416
# The 642 batch, training loss is 0.2286013960838318
# The 643 batch, training loss is 0.17648471891880035
# The 644 batch, training loss is 0.27445241808891296
# The 645 batch, training loss is 0.2004464864730835
# The 646 batch, training loss is 0.12604835629463196
# The 647 batch, training loss is 0.15545925498008728
# The 648 batch, training loss is 0.1621609926223755
# The 649 batch, training loss is 0.22478824853897095
# The 650 batch, training loss is 0.059529222548007965
# The 651 batch, training loss is 0.10700047016143799
# The 652 batch, training loss is 0.35491305589675903
# The 653 batch, training loss is 0.08304369449615479
# The 654 batch, training loss is 0.049120377749204636
# The 655 batch, training loss is 0.2810676693916321
# The 656 batch, training loss is 0.21251721680164337
# The 657 batch, training loss is 0.26391929388046265
# The 658 batch, training loss is 0.18625636398792267
# The 659 batch, training loss is 0.15186724066734314
# The 660 batch, training loss is 0.08228565007448196
# The 661 batch, training loss is 0.23576058447360992
# The 662 batch, training loss is 0.1493297517299652
# The 663 batch, training loss is 0.04072301462292671
# The 664 batch, training loss is 0.18582753837108612
# The 665 batch, training loss is 0.1834525614976883
# The 666 batch, training loss is 0.34916582703590393
# The 667 batch, training loss is 0.1444140523672104
# The 668 batch, training loss is 0.11260531097650528
# The 669 batch, training loss is 0.1345619410276413
# The 670 batch, training loss is 0.1231970265507698
# The 671 batch, training loss is 0.10763582587242126
# The 672 batch, training loss is 0.04242008551955223
# The 673 batch, training loss is 0.11883355677127838
# The 674 batch, training loss is 0.2223854511976242
# The 675 batch, training loss is 0.11086487025022507
# The 676 batch, training loss is 0.07016309350728989
# The 677 batch, training loss is 0.2111232429742813
# The 678 batch, training loss is 0.0882210060954094
# The 679 batch, training loss is 0.1439364105463028
# The 680 batch, training loss is 0.10160424560308456
# The 681 batch, training loss is 0.054992545396089554
# The 682 batch, training loss is 0.015555630438029766
# The 683 batch, training loss is 0.15567025542259216
# The 684 batch, training loss is 0.1322326958179474
# The 685 batch, training loss is 0.20679759979248047
# The 686 batch, training loss is 0.11510603129863739
# The 687 batch, training loss is 0.13487602770328522
# The 688 batch, training loss is 0.03798653557896614
# The 689 batch, training loss is 0.20325540006160736
# The 690 batch, training loss is 0.2502261996269226
# The 691 batch, training loss is 0.2574262320995331
# The 692 batch, training loss is 0.03687959164381027
# The 693 batch, training loss is 0.11483777314424515
# The 694 batch, training loss is 0.16403262317180634
# The 695 batch, training loss is 0.03314458578824997
# The 696 batch, training loss is 0.14674223959445953
# The 697 batch, training loss is 0.15856297314167023
# The 698 batch, training loss is 0.04596862196922302
# The 699 batch, training loss is 0.040070682764053345
# The 700 batch, training loss is 0.1195584088563919
# The 701 batch, training loss is 0.13663458824157715
# The 702 batch, training loss is 0.037907324731349945
# The 703 batch, training loss is 0.08391965925693512
# The 704 batch, training loss is 0.17271506786346436
# The 705 batch, training loss is 0.12419860064983368
# The 706 batch, training loss is 0.15473997592926025
# The 707 batch, training loss is 0.1694919914007187
# The 708 batch, training loss is 0.1771889626979828
# The 709 batch, training loss is 0.11284240335226059
# The 710 batch, training loss is 0.21993467211723328
# The 711 batch, training loss is 0.07915806025266647
# The 712 batch, training loss is 0.13707591593265533
# The 713 batch, training loss is 0.10638756304979324
# The 714 batch, training loss is 0.10132758319377899
# The 715 batch, training loss is 0.13630306720733643
# The 716 batch, training loss is 0.09494686126708984
# The 717 batch, training loss is 0.35495349764823914
# The 718 batch, training loss is 0.1270364671945572
# The 719 batch, training loss is 0.09896442294120789
# The 720 batch, training loss is 0.13306069374084473
# The 721 batch, training loss is 0.1491260677576065
# The 722 batch, training loss is 0.18891791999340057
# The 723 batch, training loss is 0.1800144761800766
# The 724 batch, training loss is 0.13487747311592102
# The 725 batch, training loss is 0.17881262302398682
# The 726 batch, training loss is 0.20952676236629486
# The 727 batch, training loss is 0.16984188556671143
# The 728 batch, training loss is 0.11790265142917633
# The 729 batch, training loss is 0.20308052003383636
# The 730 batch, training loss is 0.16423919796943665
# The 731 batch, training loss is 0.06781305372714996
# The 732 batch, training loss is 0.10859202593564987
# The 733 batch, training loss is 0.19075720012187958
# The 734 batch, training loss is 0.04794163256883621
# The 735 batch, training loss is 0.18977518379688263
# The 736 batch, training loss is 0.13593773543834686
# The 737 batch, training loss is 0.168173685669899
# The 738 batch, training loss is 0.18977506458759308
# The 739 batch, training loss is 0.04317548871040344
# The 740 batch, training loss is 0.07513301074504852
# The 741 batch, training loss is 0.11500462144613266
# The 742 batch, training loss is 0.08439798653125763
# The 743 batch, training loss is 0.11159555613994598
# The 744 batch, training loss is 0.13317914307117462
# The 745 batch, training loss is 0.17959178984165192
# The 746 batch, training loss is 0.10374109447002411
# The 747 batch, training loss is 0.12005671113729477
# The 748 batch, training loss is 0.05532268062233925
# The 749 batch, training loss is 0.1069902554154396
# The 750 batch, training loss is 0.09874150902032852
# The 751 batch, training loss is 0.15859507024288177
# The 752 batch, training loss is 0.18571524322032928
# The 753 batch, training loss is 0.12048180401325226
# The 754 batch, training loss is 0.10705572366714478
# The 755 batch, training loss is 0.06546436995267868
# The 756 batch, training loss is 0.10330294072628021
# The 757 batch, training loss is 0.3729281425476074
# The 758 batch, training loss is 0.2696766257286072
# The 759 batch, training loss is 0.20922015607357025
# The 760 batch, training loss is 0.07364820688962936
# The 761 batch, training loss is 0.13142207264900208
# The 762 batch, training loss is 0.19131813943386078
# The 763 batch, training loss is 0.17089641094207764
# The 764 batch, training loss is 0.11621305346488953
# The 765 batch, training loss is 0.10583368688821793
# The 766 batch, training loss is 0.13963817059993744
# The 767 batch, training loss is 0.12293598800897598
# The 768 batch, training loss is 0.06824794411659241
# The 769 batch, training loss is 0.07355941087007523
# The 770 batch, training loss is 0.31123238801956177
# The 771 batch, training loss is 0.0886746272444725
# The 772 batch, training loss is 0.23444022238254547
# The 773 batch, training loss is 0.11054161936044693
# The 774 batch, training loss is 0.14987336099147797
# The 775 batch, training loss is 0.05509991571307182
# The 776 batch, training loss is 0.050554078072309494
# The 777 batch, training loss is 0.1836548000574112
# The 778 batch, training loss is 0.10239263623952866
# The 779 batch, training loss is 0.0551452562212944
# The 780 batch, training loss is 0.057044725865125656
# The 781 batch, training loss is 0.15605442225933075
# The 782 batch, training loss is 0.21601234376430511
# The 783 batch, training loss is 0.17784973978996277
# The 784 batch, training loss is 0.17129215598106384
# The 785 batch, training loss is 0.03521983325481415
# The 786 batch, training loss is 0.1058325245976448
# The 787 batch, training loss is 0.0283527672290802
# The 788 batch, training loss is 0.24285921454429626
# The 789 batch, training loss is 0.1650126576423645
# The 790 batch, training loss is 0.06803376972675323
# The 791 batch, training loss is 0.22285330295562744
# The 792 batch, training loss is 0.06939071416854858
# The 793 batch, training loss is 0.24232566356658936
# The 794 batch, training loss is 0.1561303436756134
# The 795 batch, training loss is 0.13124005496501923
# The 796 batch, training loss is 0.09998928010463715
# The 797 batch, training loss is 0.18415546417236328
# The 798 batch, training loss is 0.017254691570997238
# The 799 batch, training loss is 0.08477019518613815
# The 800 batch, training loss is 0.17837272584438324
# The 801 batch, training loss is 0.03322632983326912
# The 802 batch, training loss is 0.2073260396718979
# The 803 batch, training loss is 0.08367504179477692
# The 804 batch, training loss is 0.17034462094306946
# The 805 batch, training loss is 0.04481108486652374
# The 806 batch, training loss is 0.07110628485679626
# The 807 batch, training loss is 0.08375759422779083
# The 808 batch, training loss is 0.20020754635334015
# The 809 batch, training loss is 0.06500652432441711
# The 810 batch, training loss is 0.22823984920978546
# The 811 batch, training loss is 0.16032101213932037
# The 812 batch, training loss is 0.09047293663024902
# The 813 batch, training loss is 0.12105470895767212
# The 814 batch, training loss is 0.04303373023867607
# The 815 batch, training loss is 0.039683569222688675
# The 816 batch, training loss is 0.06801079958677292
# The 817 batch, training loss is 0.04967302829027176
# The 818 batch, training loss is 0.018986953422427177
# The 819 batch, training loss is 0.06722142547369003
# The 820 batch, training loss is 0.2321663200855255
# The 821 batch, training loss is 0.27063867449760437
# The 822 batch, training loss is 0.1089850440621376
# The 823 batch, training loss is 0.07235757261514664
# The 824 batch, training loss is 0.07549344003200531
# The 825 batch, training loss is 0.129100501537323
# The 826 batch, training loss is 0.3056608736515045
# The 827 batch, training loss is 0.20665696263313293
# The 828 batch, training loss is 0.18137642741203308
# The 829 batch, training loss is 0.29112565517425537
# The 830 batch, training loss is 0.22243613004684448
# The 831 batch, training loss is 0.11769147962331772
# The 832 batch, training loss is 0.1511210799217224
# The 833 batch, training loss is 0.24622415006160736
# The 834 batch, training loss is 0.1462053656578064
# The 835 batch, training loss is 0.027880441397428513
# The 836 batch, training loss is 0.07759139686822891
# The 837 batch, training loss is 0.07634732127189636
# The 838 batch, training loss is 0.14532743394374847
# The 839 batch, training loss is 0.20487983524799347
# The 840 batch, training loss is 0.04745209589600563
# The 841 batch, training loss is 0.12745365500450134
# The 842 batch, training loss is 0.09712585806846619
# The 843 batch, training loss is 0.15000736713409424
# The 844 batch, training loss is 0.23070071637630463
# The 845 batch, training loss is 0.17090846598148346
# The 846 batch, training loss is 0.274039626121521
# The 847 batch, training loss is 0.042973220348358154
# The 848 batch, training loss is 0.025564758107066154
# The 849 batch, training loss is 0.027038870379328728
# The 850 batch, training loss is 0.11502693593502045
# The 851 batch, training loss is 0.16056710481643677
# The 852 batch, training loss is 0.09083615988492966
# The 853 batch, training loss is 0.08917352557182312
# The 854 batch, training loss is 0.024820400401949883
# The 855 batch, training loss is 0.1282426416873932
# The 856 batch, training loss is 0.23776006698608398
# The 857 batch, training loss is 0.08707869052886963
# The 858 batch, training loss is 0.1581505388021469
# The 859 batch, training loss is 0.04274880886077881
# The 860 batch, training loss is 0.11585475504398346
# The 861 batch, training loss is 0.2043740600347519
# The 862 batch, training loss is 0.1640055775642395
# The 863 batch, training loss is 0.028981758281588554
# The 864 batch, training loss is 0.1894388496875763
# The 865 batch, training loss is 0.039085909724235535
# The 866 batch, training loss is 0.12141256034374237
# The 867 batch, training loss is 0.09239356219768524
# The 868 batch, training loss is 0.07515109330415726
# The 869 batch, training loss is 0.09990100562572479
# The 870 batch, training loss is 0.0848856195807457
# The 871 batch, training loss is 0.18431848287582397
# The 872 batch, training loss is 0.08369161933660507
# The 873 batch, training loss is 0.022137057036161423
# The 874 batch, training loss is 0.0835014209151268
# The 875 batch, training loss is 0.14967182278633118
# The 876 batch, training loss is 0.016724683344364166
# The 877 batch, training loss is 0.10570041090250015
# The 878 batch, training loss is 0.13035999238491058
# The 879 batch, training loss is 0.0743941068649292
# The 880 batch, training loss is 0.10782776772975922
# The 881 batch, training loss is 0.05787522345781326
# The 882 batch, training loss is 0.11774370074272156
# The 883 batch, training loss is 0.2108919471502304
# The 884 batch, training loss is 0.10148417949676514
# The 885 batch, training loss is 0.025083333253860474
# The 886 batch, training loss is 0.05239596590399742
# The 887 batch, training loss is 0.14656572043895721
# The 888 batch, training loss is 0.04520689696073532
# The 889 batch, training loss is 0.0992765724658966
# The 890 batch, training loss is 0.04456276819109917
# The 891 batch, training loss is 0.05267767608165741
# The 892 batch, training loss is 0.07498368620872498
# The 893 batch, training loss is 0.1236146092414856
# The 894 batch, training loss is 0.09066440910100937
# The 895 batch, training loss is 0.03141272813081741
# The 896 batch, training loss is 0.14709700644016266
# The 897 batch, training loss is 0.1645238697528839
# The 898 batch, training loss is 0.0527154877781868
# The 899 batch, training loss is 0.08632063865661621
# The 900 batch, training loss is 0.049275703728199005
# The 901 batch, training loss is 0.20386286079883575
# The 902 batch, training loss is 0.05268632248044014
# The 903 batch, training loss is 0.14511911571025848
# The 904 batch, training loss is 0.20258569717407227
# The 905 batch, training loss is 0.14133301377296448
# The 906 batch, training loss is 0.10001656413078308
# The 907 batch, training loss is 0.08639694005250931
# The 908 batch, training loss is 0.06891399621963501
# The 909 batch, training loss is 0.20640750229358673
# The 910 batch, training loss is 0.15069836378097534
# The 911 batch, training loss is 0.15706421434879303
# The 912 batch, training loss is 0.020989693701267242
# The 913 batch, training loss is 0.2375449538230896
# The 914 batch, training loss is 0.07717163860797882
# The 915 batch, training loss is 0.22944167256355286
# The 916 batch, training loss is 0.09411007165908813
# The 917 batch, training loss is 0.16777876019477844
# The 918 batch, training loss is 0.08465263247489929
# The 919 batch, training loss is 0.09513063728809357
# The 920 batch, training loss is 0.1734962910413742
# The 921 batch, training loss is 0.07805704325437546
# The 922 batch, training loss is 0.15231932699680328
# The 923 batch, training loss is 0.153676375746727
# The 924 batch, training loss is 0.09366822242736816
# The 925 batch, training loss is 0.3065829873085022
# The 926 batch, training loss is 0.10169593244791031
# The 927 batch, training loss is 0.15340101718902588
# The 928 batch, training loss is 0.021081751212477684
# The 929 batch, training loss is 0.12546266615390778
# ...
# The 131 batch, test loss is 0.716164767742157
# The 132 batch, test loss is 0.5349682569503784
# The 133 batch, test loss is 0.6144229769706726
# The 134 batch, test loss is 0.5101479887962341
# The 135 batch, test loss is 0.2883855104446411
# The 136 batch, test loss is 0.24980708956718445
# The 137 batch, test loss is 0.3125114440917969
# The 138 batch, test loss is 0.32968229055404663
# The 139 batch, test loss is 0.44950631260871887
# The 140 batch, test loss is 0.9455469846725464
# The 141 batch, test loss is 0.8690638542175293
# The 142 batch, test loss is 0.742257833480835
# The 143 batch, test loss is 0.6137621402740479
# The 144 batch, test loss is 0.5835402607917786
# The 145 batch, test loss is 0.41297125816345215
# The 146 batch, test loss is 0.48610952496528625
# The 147 batch, test loss is 0.5917948484420776
# The 148 batch, test loss is 0.5790714621543884
# The 149 batch, test loss is 0.5546293258666992
# The 150 batch, test loss is 0.7120976448059082
# The 151 batch, test loss is 0.7604339718818665
# The 152 batch, test loss is 1.2513996362686157
# The 153 batch, test loss is 0.9913679957389832
# The 154 batch, test loss is 1.2116855382919312
# The 155 batch, test loss is 1.1103699207305908
# The 156 batch, test loss is 0.444139689207077
# The 7 model, test loss is 0.7577573590597529
# The 0 batch, training loss is 2.6151845455169678
# The 1 batch, training loss is 2.2573752403259277
# The 2 batch, training loss is 3.1783297061920166
# The 0 batch, test loss is 1.6579701900482178
# The 1 batch, test loss is 1.6188068389892578
# The 2 batch, test loss is 1.6873202323913574
# The 3 batch, test loss is 1.6993212699890137
# The 4 batch, test loss is 1.7017604112625122
# The 5 batch, test loss is 1.8087158203125
# The 6 batch, test loss is 1.8046045303344727
# The 7 batch, test loss is 1.8416287899017334
# The 8 batch, test loss is 1.8089343309402466
# The 9 batch, test loss is 1.8742940425872803
# The 10 batch, test loss is 1.5973305702209473
# The 11 batch, test loss is 1.5245050191879272
# The 12 batch, test loss is 1.3959604501724243
# The 13 batch, test loss is 1.7601978778839111
# The 14 batch, test loss is 1.7225372791290283
# The 15 batch, test loss is 1.683189868927002
# The 16 batch, test loss is 1.6779059171676636
# The 17 batch, test loss is 1.8379253149032593
# The 18 batch, test loss is 1.8040118217468262
# The 19 batch, test loss is 1.8453072309494019
# The 20 batch, test loss is 1.708066463470459
# The 21 batch, test loss is 1.836485743522644
# The 22 batch, test loss is 2.0089731216430664
# The 23 batch, test loss is 1.6968188285827637
# The 24 batch, test loss is 1.702881932258606
# The 25 batch, test loss is 1.7545562982559204
# The 26 batch, test loss is 1.6555672883987427
# The 27 batch, test loss is 1.693058729171753
# The 28 batch, test loss is 1.6787662506103516
# The 29 batch, test loss is 1.846729040145874
# The 30 batch, test loss is 1.7788532972335815
# The 31 batch, test loss is 1.7943110466003418
# The 32 batch, test loss is 1.8232700824737549
# The 33 batch, test loss is 1.7266111373901367
# The 34 batch, test loss is 2.0229647159576416
# The 35 batch, test loss is 1.6412301063537598
# The 36 batch, test loss is 1.4726577997207642
# The 37 batch, test loss is 1.6654490232467651
# The 38 batch, test loss is 2.053617477416992
# The 39 batch, test loss is 1.9628608226776123
# The 40 batch, test loss is 1.8385823965072632
# The 41 batch, test loss is 1.683646559715271
# The 42 batch, test loss is 1.8274402618408203
# The 43 batch, test loss is 1.880921483039856
# The 44 batch, test loss is 1.5495634078979492
# The 45 batch, test loss is 1.6908268928527832
# The 46 batch, test loss is 2.0531227588653564
# The 47 batch, test loss is 1.569808840751648
# The 48 batch, test loss is 1.6452245712280273
# The 49 batch, test loss is 1.7107038497924805
# The 50 batch, test loss is 1.5714646577835083
# The 51 batch, test loss is 1.738020658493042
# The 52 batch, test loss is 1.7805691957473755
# The 53 batch, test loss is 1.8140368461608887
# The 54 batch, test loss is 1.882081389427185
# The 55 batch, test loss is 1.817962884902954
# The 56 batch, test loss is 1.5291125774383545
# The 57 batch, test loss is 1.6951653957366943
# The 58 batch, test loss is 1.7372255325317383
# The 59 batch, test loss is 2.077993154525757
# The 60 batch, test loss is 1.9889010190963745
# The 61 batch, test loss is 1.8992599248886108
# The 62 batch, test loss is 1.4249979257583618
# The 63 batch, test loss is 1.6152427196502686
# The 64 batch, test loss is 1.8150947093963623
# The 65 batch, test loss is 1.7337095737457275
# The 66 batch, test loss is 1.959150791168213
# The 67 batch, test loss is 1.8985235691070557
# The 68 batch, test loss is 1.919391393661499
# The 69 batch, test loss is 2.003244400024414
# The 70 batch, test loss is 1.7325406074523926
# The 71 batch, test loss is 1.6773955821990967
# The 72 batch, test loss is 1.5774734020233154
# The 73 batch, test loss is 1.8327134847640991
# The 74 batch, test loss is 1.494422435760498
# The 75 batch, test loss is 1.8316963911056519
# The 76 batch, test loss is 1.7573355436325073
# The 77 batch, test loss is 1.8215985298156738
# The 78 batch, test loss is 1.4639497995376587
# The 79 batch, test loss is 1.6653589010238647
# The 80 batch, test loss is 1.4630073308944702
# The 81 batch, test loss is 1.5788559913635254
# The 82 batch, test loss is 1.674943447113037
# The 83 batch, test loss is 1.4255385398864746
# The 84 batch, test loss is 1.6021372079849243
# The 85 batch, test loss is 1.2674620151519775
# The 86 batch, test loss is 1.5579437017440796
# The 87 batch, test loss is 1.6986016035079956
# The 88 batch, test loss is 1.5930970907211304
# The 89 batch, test loss is 1.6588729619979858
# The 90 batch, test loss is 1.4267990589141846
# The 91 batch, test loss is 1.7342573404312134
# The 92 batch, test loss is 1.879845142364502
# The 93 batch, test loss is 1.8094046115875244
# The 94 batch, test loss is 1.7378886938095093
# The 95 batch, test loss is 1.4093401432037354
# The 96 batch, test loss is 1.5901676416397095
# The 97 batch, test loss is 1.509483814239502
# The 98 batch, test loss is 1.4225196838378906
# The 99 batch, test loss is 1.3705004453659058
# The 100 batch, test loss is 1.6491905450820923
# The 101 batch, test loss is 1.7567884922027588
# The 102 batch, test loss is 1.6621017456054688
# The 103 batch, test loss is 1.8571979999542236
# The 104 batch, test loss is 1.7265772819519043
# The 105 batch, test loss is 1.6510545015335083
# The 106 batch, test loss is 1.9748550653457642
# The 107 batch, test loss is 1.6313573122024536
# The 108 batch, test loss is 1.7187968492507935
# The 109 batch, test loss is 1.7795897722244263
# The 110 batch, test loss is 1.6076868772506714
# The 111 batch, test loss is 2.037226915359497
# The 112 batch, test loss is 1.6277164220809937
# The 113 batch, test loss is 1.921022653579712
# The 114 batch, test loss is 1.7139458656311035
# The 115 batch, test loss is 1.8390394449234009
# The 116 batch, test loss is 2.116851806640625
# The 117 batch, test loss is 1.907965898513794
# The 118 batch, test loss is 1.8901621103286743
# The 119 batch, test loss is 1.6453313827514648
# The 120 batch, test loss is 1.6127899885177612
# The 121 batch, test loss is 1.7191309928894043
# The 122 batch, test loss is 1.8692907094955444
# The 123 batch, test loss is 1.9502308368682861
# The 124 batch, test loss is 1.4924298524856567
# The 125 batch, test loss is 1.602553129196167
# The 126 batch, test loss is 1.722013235092163
# The 127 batch, test loss is 1.591468095779419
# The 128 batch, test loss is 1.5964679718017578
# The 129 batch, test loss is 1.6202967166900635
# The 130 batch, test loss is 1.80711829662323
# The 131 batch, test loss is 1.4782387018203735
# The 132 batch, test loss is 1.340001106262207
# The 133 batch, test loss is 1.4406447410583496
# The 134 batch, test loss is 1.5151307582855225
# The 135 batch, test loss is 1.5514572858810425
# The 136 batch, test loss is 1.4630085229873657
# The 137 batch, test loss is 1.462561011314392
# The 138 batch, test loss is 1.527206301689148
# The 139 batch, test loss is 1.5608558654785156
# The 140 batch, test loss is 1.6925512552261353
# The 141 batch, test loss is 1.6324448585510254
# The 142 batch, test loss is 1.4440791606903076
# The 143 batch, test loss is 1.7702687978744507
# The 144 batch, test loss is 1.7564821243286133
# The 145 batch, test loss is 1.3659683465957642
# The 146 batch, test loss is 1.4112316370010376
# The 147 batch, test loss is 1.5473078489303589
# The 148 batch, test loss is 1.6609245538711548
# The 149 batch, test loss is 1.7350672483444214
# The 150 batch, test loss is 1.7018152475357056
# The 151 batch, test loss is 1.8537309169769287
# The 152 batch, test loss is 2.0911989212036133
# The 153 batch, test loss is 1.7516772747039795
# The 154 batch, test loss is 1.9628727436065674
# The 155 batch, test loss is 1.86366868019104
# The 156 batch, test loss is 1.6009776592254639
# The 8 model, test loss is 1.7068262282450488
# The 0 batch, training loss is 2.8951966762542725
# The 0 batch, test loss is 2.5132837295532227
# The 1 batch, test loss is 2.452092170715332
# The 2 batch, test loss is 2.6742379665374756
# The 3 batch, test loss is 2.6834700107574463
# The 4 batch, test loss is 2.823103904724121
# The 5 batch, test loss is 2.6932685375213623
# The 6 batch, test loss is 2.621865749359131
# The 7 batch, test loss is 2.4526071548461914
# The 8 batch, test loss is 2.3852834701538086
# The 9 batch, test loss is 2.5556349754333496
# The 10 batch, test loss is 2.6563210487365723
# The 11 batch, test loss is 2.5271658897399902
# The 12 batch, test loss is 2.429755926132202
# The 13 batch, test loss is 2.668286085128784
# The 14 batch, test loss is 2.6663389205932617
# The 15 batch, test loss is 2.8624885082244873
# The 16 batch, test loss is 2.6210758686065674
# The 17 batch, test loss is 2.642916202545166
# The 18 batch, test loss is 2.597243309020996
# The 19 batch, test loss is 2.7147557735443115
# The 20 batch, test loss is 2.6497719287872314
# The 21 batch, test loss is 2.9715306758880615
# The 22 batch, test loss is 2.673269748687744
# The 23 batch, test loss is 2.6314697265625
# The 24 batch, test loss is 2.436774730682373
# The 25 batch, test loss is 2.591057538986206
# The 26 batch, test loss is 2.586290121078491
# The 27 batch, test loss is 2.4991848468780518
# The 28 batch, test loss is 2.5572056770324707
# The 29 batch, test loss is 2.6650524139404297
# The 30 batch, test loss is 2.416276693344116
# The 31 batch, test loss is 2.4241490364074707
# The 32 batch, test loss is 2.736138343811035
# The 33 batch, test loss is 2.593132972717285
# The 34 batch, test loss is 2.7615749835968018
# The 35 batch, test loss is 2.750171422958374
# The 36 batch, test loss is 2.5070436000823975
# The 37 batch, test loss is 2.5472729206085205
# The 38 batch, test loss is 2.8417744636535645
# The 39 batch, test loss is 2.6751322746276855
# The 40 batch, test loss is 2.760309934616089
# The 41 batch, test loss is 2.524670124053955
# The 42 batch, test loss is 2.4386956691741943
# The 43 batch, test loss is 2.382294178009033
# The 44 batch, test loss is 2.4906158447265625
# The 45 batch, test loss is 2.5033271312713623
# The 46 batch, test loss is 2.49365234375
# The 47 batch, test loss is 2.5676567554473877
# The 48 batch, test loss is 2.6597347259521484
# The 49 batch, test loss is 2.513711452484131
# The 50 batch, test loss is 2.835510730743408
# The 51 batch, test loss is 2.6779062747955322
# The 52 batch, test loss is 2.5981061458587646
# The 53 batch, test loss is 2.580934762954712
# The 54 batch, test loss is 2.494636058807373
# The 55 batch, test loss is 2.3482048511505127
# The 56 batch, test loss is 2.6213924884796143
# The 57 batch, test loss is 2.7110719680786133
# The 58 batch, test loss is 2.507742166519165
# The 59 batch, test loss is 2.756627082824707
# The 60 batch, test loss is 2.551858425140381
# The 61 batch, test loss is 2.6138875484466553
# The 62 batch, test loss is 2.2371742725372314
# The 63 batch, test loss is 2.7219884395599365
# The 64 batch, test loss is 2.8743300437927246
# The 65 batch, test loss is 2.78045916557312
# The 66 batch, test loss is 2.607013702392578
# The 67 batch, test loss is 2.6879098415374756
# The 68 batch, test loss is 2.5831918716430664
# The 69 batch, test loss is 2.7006101608276367
# The 70 batch, test loss is 2.481238842010498
# The 71 batch, test loss is 2.53235125541687
# The 72 batch, test loss is 2.377971649169922
# The 73 batch, test loss is 2.842956304550171
# The 74 batch, test loss is 2.3655760288238525
# The 75 batch, test loss is 2.506582021713257
# The 76 batch, test loss is 2.672226667404175
# The 77 batch, test loss is 2.8084893226623535
# The 78 batch, test loss is 2.339235782623291
# The 79 batch, test loss is 2.392273187637329
# The 80 batch, test loss is 2.24912166595459
# The 81 batch, test loss is 2.400688886642456
# The 82 batch, test loss is 2.5504696369171143
# The 83 batch, test loss is 2.5400185585021973
# The 84 batch, test loss is 2.5560948848724365
# The 85 batch, test loss is 2.4899399280548096
# The 86 batch, test loss is 2.9371299743652344
# The 87 batch, test loss is 2.4915757179260254
# The 88 batch, test loss is 2.8485658168792725
# The 89 batch, test loss is 2.5951755046844482
# The 90 batch, test loss is 2.483187437057495
# The 91 batch, test loss is 2.6623892784118652
# The 92 batch, test loss is 2.7250754833221436
# The 93 batch, test loss is 2.7042815685272217
# The 94 batch, test loss is 2.7194976806640625
# The 95 batch, test loss is 2.524026393890381
# The 96 batch, test loss is 2.483839988708496
# The 97 batch, test loss is 2.5022644996643066
# The 98 batch, test loss is 2.4469220638275146
# The 99 batch, test loss is 2.5337250232696533
# The 100 batch, test loss is 2.578864336013794
# The 101 batch, test loss is 2.495211362838745
# The 102 batch, test loss is 2.455915927886963
# The 103 batch, test loss is 2.533658027648926
# The 104 batch, test loss is 2.177140951156616
# The 105 batch, test loss is 2.4060232639312744
# The 106 batch, test loss is 2.627210855484009
# The 107 batch, test loss is 2.527095317840576
# The 108 batch, test loss is 2.4931352138519287
# The 109 batch, test loss is 2.826690435409546
# The 110 batch, test loss is 2.537943124771118
# The 111 batch, test loss is 2.5843851566314697
# The 112 batch, test loss is 2.1549694538116455
# The 113 batch, test loss is 2.442831039428711
# The 114 batch, test loss is 2.6847097873687744
# The 115 batch, test loss is 2.5538504123687744
# The 116 batch, test loss is 2.5096936225891113
# The 117 batch, test loss is 2.4913506507873535
# The 118 batch, test loss is 2.718046188354492
# The 119 batch, test loss is 2.56962513923645
# The 120 batch, test loss is 2.620999574661255
# The 121 batch, test loss is 2.3589675426483154
# The 122 batch, test loss is 2.3322556018829346
# The 123 batch, test loss is 2.520761251449585
# The 124 batch, test loss is 2.375156879425049
# The 125 batch, test loss is 2.371656656265259
# The 126 batch, test loss is 2.6494174003601074
# The 127 batch, test loss is 2.320939064025879
# The 128 batch, test loss is 2.211705207824707
# The 129 batch, test loss is 2.2606818675994873
# The 130 batch, test loss is 2.226808786392212
# The 131 batch, test loss is 2.2180769443511963
# The 132 batch, test loss is 2.398937940597534
# The 133 batch, test loss is 2.6638710498809814
# The 134 batch, test loss is 2.510761260986328
# The 135 batch, test loss is 2.4723966121673584
# The 136 batch, test loss is 2.6180737018585205
# The 137 batch, test loss is 2.1795825958251953
# The 138 batch, test loss is 2.3312439918518066
# The 139 batch, test loss is 2.3060717582702637
# The 140 batch, test loss is 2.1070973873138428
# The 141 batch, test loss is 2.544370412826538
# The 142 batch, test loss is 2.6683950424194336
# The 143 batch, test loss is 2.262321710586548
# The 144 batch, test loss is 2.029052495956421
# The 145 batch, test loss is 2.387277126312256
# The 146 batch, test loss is 2.3880085945129395
# The 147 batch, test loss is 2.489628791809082
# The 148 batch, test loss is 2.5308473110198975
# The 149 batch, test loss is 2.515604257583618
# The 150 batch, test loss is 2.3428750038146973
# The 151 batch, test loss is 2.4548580646514893
# The 152 batch, test loss is 2.5386102199554443
# The 153 batch, test loss is 2.774641990661621
# The 154 batch, test loss is 2.4999232292175293
# The 155 batch, test loss is 2.3809850215911865
# The 156 batch, test loss is 2.7667746543884277
# The 9 model, test loss is 2.543576890495932

# %% [markdown]
# ## Training modles with different dataset size

# %%
dataset_size = [1, 1/2, 1/4, 1/8, 1/16, 1/32, 1/64, 1/128, 1/256, 1/512]
plt.plot(dataset_size, losses_1)
plt.xscale('log') # Adjusts the x-axis to a log scale
plt.yscale('log')
plt.title("training loss over time with different dataset size")
plt.xlabel('dataset size (big to small)')
plt.ylabel('Test Loss')
plt.show()

# %%
losses_2 = []
train_eval_process = traineval(criterion)
for idx, model in enumerate(models):
  model.to(device)  # Move each model to the appropriate device before evaluation
  loss = train_eval_process.eval(sub_train_dataloaders[0], test_dataloader, model, optimizers[idx])  # we train the model with only 0.1 with all the train data. Smaller dataset, less complexity (also it starts with the same configuration of the one with the training dataset size exp)
  print(f'The {idx} model, test loss is {loss}')
  losses_2.append(loss)
model_size = [8,11,16,23,32,45,64,91,128,181]
plt.plot(model_size, losses_2)
plt.title("training loss over time with different model size")
plt.xlabel('Model size (by number of filters in CNN)')
plt.ylabel('Test Loss')
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# The 475 batch, training loss is 0.22235581278800964
# The 476 batch, training loss is 0.23906350135803223
# The 477 batch, training loss is 0.3017275929450989
# The 478 batch, training loss is 0.2635040581226349
# The 479 batch, training loss is 0.20638537406921387
# The 480 batch, training loss is 0.14313924312591553
# The 481 batch, training loss is 0.30673590302467346
# The 482 batch, training loss is 0.16295161843299866
# The 483 batch, training loss is 0.12807852029800415
# The 484 batch, training loss is 0.12532027065753937
# The 485 batch, training loss is 0.2418193817138672
# The 486 batch, training loss is 0.2619810700416565
# The 487 batch, training loss is 0.16042578220367432
# The 488 batch, training loss is 0.22563967108726501
# The 489 batch, training loss is 0.15158109366893768
# The 490 batch, training loss is 0.0792086124420166
# The 491 batch, training loss is 0.0981205552816391
# The 492 batch, training loss is 0.09631481766700745
# The 493 batch, training loss is 0.20812761783599854
# The 494 batch, training loss is 0.2506972849369049
# The 495 batch, training loss is 0.2097082883119583
# The 496 batch, training loss is 0.41613003611564636
# The 497 batch, training loss is 0.1311751753091812
# The 498 batch, training loss is 0.2159222662448883
# The 499 batch, training loss is 0.12384174764156342
# The 500 batch, training loss is 0.16660065948963165
# The 501 batch, training loss is 0.21475045382976532
# The 502 batch, training loss is 0.09612476080656052
# The 503 batch, training loss is 0.11679454892873764
# The 504 batch, training loss is 0.11644372344017029
# The 505 batch, training loss is 0.20971724390983582
# The 506 batch, training loss is 0.34480103850364685
# The 507 batch, training loss is 0.11599652469158173
# The 508 batch, training loss is 0.09633541107177734
# The 509 batch, training loss is 0.265299916267395
# The 510 batch, training loss is 0.13242246210575104
# The 511 batch, training loss is 0.1260141134262085
# The 512 batch, training loss is 0.2577115297317505
# The 513 batch, training loss is 0.11509520560503006
# The 514 batch, training loss is 0.17706598341464996
# The 515 batch, training loss is 0.1770869493484497
# The 516 batch, training loss is 0.17172227799892426
# The 517 batch, training loss is 0.10622108727693558
# The 518 batch, training loss is 0.33244436979293823
# The 519 batch, training loss is 0.24876247346401215
# The 520 batch, training loss is 0.2996918261051178
# The 521 batch, training loss is 0.17015676200389862
# The 522 batch, training loss is 0.20104585587978363
# The 523 batch, training loss is 0.23251846432685852
# The 524 batch, training loss is 0.2733536958694458
# The 525 batch, training loss is 0.3450557291507721
# The 526 batch, training loss is 0.14544817805290222
# The 527 batch, training loss is 0.12530456483364105
# The 528 batch, training loss is 0.23301072418689728
# The 529 batch, training loss is 0.2758745551109314
# The 530 batch, training loss is 0.19159239530563354
# The 531 batch, training loss is 0.20973999798297882
# The 532 batch, training loss is 0.06963662058115005
# The 533 batch, training loss is 0.4640432596206665
# The 534 batch, training loss is 0.19850750267505646
# The 535 batch, training loss is 0.1361583024263382
# The 536 batch, training loss is 0.27494534850120544
# The 537 batch, training loss is 0.4252278506755829
# The 538 batch, training loss is 0.22476786375045776
# The 539 batch, training loss is 0.11578388512134552
# The 540 batch, training loss is 0.2872448265552521
# The 541 batch, training loss is 0.21433265507221222
# The 542 batch, training loss is 0.10418084263801575
# The 543 batch, training loss is 0.168421670794487
# The 544 batch, training loss is 0.15657922625541687
# The 545 batch, training loss is 0.1760873645544052
# The 546 batch, training loss is 0.11581992357969284
# The 547 batch, training loss is 0.2937093675136566
# The 548 batch, training loss is 0.18427540361881256
# The 549 batch, training loss is 0.30665892362594604
# The 550 batch, training loss is 0.2231440544128418
# The 551 batch, training loss is 0.15931956470012665
# The 552 batch, training loss is 0.22435306012630463
# The 553 batch, training loss is 0.15576021373271942
# The 554 batch, training loss is 0.21637223660945892
# The 555 batch, training loss is 0.10668845474720001
# The 556 batch, training loss is 0.16173143684864044
# The 557 batch, training loss is 0.10424165427684784
# The 558 batch, training loss is 0.11293909698724747
# The 559 batch, training loss is 0.1433868259191513
# The 560 batch, training loss is 0.20324213802814484
# The 561 batch, training loss is 0.26332011818885803
# The 562 batch, training loss is 0.11352431774139404
# The 563 batch, training loss is 0.12003207951784134
# The 564 batch, training loss is 0.10378633439540863
# The 565 batch, training loss is 0.12942124903202057
# The 566 batch, training loss is 0.15953589975833893
# The 567 batch, training loss is 0.2532387971878052
# The 568 batch, training loss is 0.07992365211248398
# The 569 batch, training loss is 0.1290760040283203
# The 570 batch, training loss is 0.25185051560401917
# The 571 batch, training loss is 0.10626605898141861
# The 572 batch, training loss is 0.1864515244960785
# The 573 batch, training loss is 0.21088124811649323
# The 574 batch, training loss is 0.14417923986911774
# The 575 batch, training loss is 0.2196737378835678
# The 576 batch, training loss is 0.05973808094859123
# The 577 batch, training loss is 0.4732418358325958
# The 578 batch, training loss is 0.14169833064079285
# The 579 batch, training loss is 0.10089274495840073
# The 580 batch, training loss is 0.09227161854505539
# The 581 batch, training loss is 0.2498450130224228
# The 582 batch, training loss is 0.21100233495235443
# The 583 batch, training loss is 0.13103245198726654
# The 584 batch, training loss is 0.25700706243515015
# The 585 batch, training loss is 0.34347060322761536
# The 586 batch, training loss is 0.1467161774635315
# The 587 batch, training loss is 0.14587189257144928
# The 588 batch, training loss is 0.20127740502357483
# The 589 batch, training loss is 0.2398642897605896
# The 590 batch, training loss is 0.2378590703010559
# The 591 batch, training loss is 0.10471908003091812
# The 592 batch, training loss is 0.13474178314208984
# The 593 batch, training loss is 0.11956676095724106
# The 594 batch, training loss is 0.12871932983398438
# The 595 batch, training loss is 0.20447397232055664
# The 596 batch, training loss is 0.17729362845420837
# The 597 batch, training loss is 0.08812236785888672
# The 598 batch, training loss is 0.12552639842033386
# The 599 batch, training loss is 0.1365213543176651
# The 600 batch, training loss is 0.09699356555938721
# The 601 batch, training loss is 0.08752874284982681
# The 602 batch, training loss is 0.15568791329860687
# The 603 batch, training loss is 0.368284672498703
# The 604 batch, training loss is 0.19034358859062195
# The 605 batch, training loss is 0.17657294869422913
# The 606 batch, training loss is 0.19803522527217865
# The 607 batch, training loss is 0.17883004248142242
# The 608 batch, training loss is 0.2631484568119049
# The 609 batch, training loss is 0.11274882405996323
# The 610 batch, training loss is 0.3463979959487915
# The 611 batch, training loss is 0.09433522075414658
# The 612 batch, training loss is 0.0949418842792511
# The 613 batch, training loss is 0.4127742648124695
# The 614 batch, training loss is 0.2146913856267929
# The 615 batch, training loss is 0.14089685678482056
# The 616 batch, training loss is 0.08053779602050781
# The 617 batch, training loss is 0.1229388639330864
# The 618 batch, training loss is 0.1886957734823227
# The 619 batch, training loss is 0.27609750628471375
# The 620 batch, training loss is 0.23678147792816162
# The 621 batch, training loss is 0.29058513045310974
# The 622 batch, training loss is 0.17146901786327362
# The 623 batch, training loss is 0.06336461752653122
# The 624 batch, training loss is 0.19353467226028442
# The 625 batch, training loss is 0.24250751733779907
# The 626 batch, training loss is 0.09106843918561935
# The 627 batch, training loss is 0.14758406579494476
# The 628 batch, training loss is 0.32327258586883545
# The 629 batch, training loss is 0.20140434801578522
# The 630 batch, training loss is 0.31241828203201294
# The 631 batch, training loss is 0.18855102360248566
# The 632 batch, training loss is 0.15848281979560852
# The 633 batch, training loss is 0.1146809458732605
# The 634 batch, training loss is 0.36190587282180786
# The 635 batch, training loss is 0.14176490902900696
# The 636 batch, training loss is 0.21764115989208221
# The 637 batch, training loss is 0.15191993117332458
# The 638 batch, training loss is 0.17193913459777832
# The 639 batch, training loss is 0.2535158395767212
# The 640 batch, training loss is 0.2567988634109497
# The 641 batch, training loss is 0.3173661231994629
# The 642 batch, training loss is 0.3232371211051941
# The 643 batch, training loss is 0.20964473485946655
# The 644 batch, training loss is 0.1597168892621994
# The 645 batch, training loss is 0.156686469912529
# The 646 batch, training loss is 0.15857091546058655
# The 647 batch, training loss is 0.07467257231473923
# The 648 batch, training loss is 0.2367939054965973
# The 649 batch, training loss is 0.0812048614025116
# The 650 batch, training loss is 0.1690616011619568
# The 651 batch, training loss is 0.3040832281112671
# The 652 batch, training loss is 0.15580123662948608
# The 653 batch, training loss is 0.18299491703510284
# The 654 batch, training loss is 0.08693129569292068
# The 655 batch, training loss is 0.1651860624551773
# The 656 batch, training loss is 0.08489871770143509
# The 657 batch, training loss is 0.24332700669765472
# The 658 batch, training loss is 0.23495379090309143
# The 659 batch, training loss is 0.1316477507352829
# The 660 batch, training loss is 0.1384720355272293
# The 661 batch, training loss is 0.10710550099611282
# The 662 batch, training loss is 0.21096394956111908
# The 663 batch, training loss is 0.11061792820692062
# The 664 batch, training loss is 0.07507703453302383
# The 665 batch, training loss is 0.2100098878145218
# The 666 batch, training loss is 0.3588179349899292
# The 667 batch, training loss is 0.10346245765686035
# The 668 batch, training loss is 0.09561171382665634
# The 669 batch, training loss is 0.056595537811517715
# The 670 batch, training loss is 0.06109732389450073
# The 671 batch, training loss is 0.18041227757930756
# The 672 batch, training loss is 0.2849178612232208
# The 673 batch, training loss is 0.11993004381656647
# The 674 batch, training loss is 0.3691236972808838
# The 675 batch, training loss is 0.2500750422477722
# The 676 batch, training loss is 0.19834475219249725
# The 677 batch, training loss is 0.1359890103340149
# The 678 batch, training loss is 0.13241888582706451
# The 679 batch, training loss is 0.13504309952259064
# The 680 batch, training loss is 0.18389765918254852
# The 681 batch, training loss is 0.1531112790107727
# The 682 batch, training loss is 0.11814071238040924
# The 683 batch, training loss is 0.09845913201570511
# The 684 batch, training loss is 0.11498381197452545
# The 685 batch, training loss is 0.09530480951070786
# The 686 batch, training loss is 0.10855583101511002
# The 687 batch, training loss is 0.1518930047750473
# The 688 batch, training loss is 0.2749582529067993
# The 689 batch, training loss is 0.13184522092342377
# The 690 batch, training loss is 0.17854660749435425
# The 691 batch, training loss is 0.13511894643306732
# The 692 batch, training loss is 0.12330860644578934
# The 693 batch, training loss is 0.25591325759887695
# The 694 batch, training loss is 0.23867174983024597
# The 695 batch, training loss is 0.2229815125465393
# The 696 batch, training loss is 0.2421172559261322
# The 697 batch, training loss is 0.13669359683990479
# The 698 batch, training loss is 0.11239416152238846
# The 699 batch, training loss is 0.196488618850708
# The 700 batch, training loss is 0.23860016465187073
# The 701 batch, training loss is 0.10104990750551224
# The 702 batch, training loss is 0.13152644038200378
# The 703 batch, training loss is 0.38316047191619873
# The 704 batch, training loss is 0.1646021157503128
# The 705 batch, training loss is 0.141534686088562
# The 706 batch, training loss is 0.14303143322467804
# The 707 batch, training loss is 0.10987876355648041
# The 708 batch, training loss is 0.25990402698516846
# The 709 batch, training loss is 0.1450827717781067
# The 710 batch, training loss is 0.24417942762374878
# The 711 batch, training loss is 0.1914616972208023
# The 712 batch, training loss is 0.061265379190444946
# The 713 batch, training loss is 0.18500205874443054
# The 714 batch, training loss is 0.2105264514684677
# The 715 batch, training loss is 0.09894409030675888
# The 716 batch, training loss is 0.12082315236330032
# The 717 batch, training loss is 0.2203828990459442
# The 718 batch, training loss is 0.19781696796417236
# The 719 batch, training loss is 0.23142214119434357
# The 720 batch, training loss is 0.08620817959308624
# The 721 batch, training loss is 0.14312376081943512
# The 722 batch, training loss is 0.11192373931407928
# The 723 batch, training loss is 0.11357510089874268
# The 724 batch, training loss is 0.15035969018936157
# The 725 batch, training loss is 0.09651884436607361
# The 726 batch, training loss is 0.26752734184265137
# The 727 batch, training loss is 0.1945878565311432
# The 728 batch, training loss is 0.13173112273216248
# The 729 batch, training loss is 0.18260988593101501
# The 730 batch, training loss is 0.0936269611120224
# The 731 batch, training loss is 0.2973087430000305
# The 732 batch, training loss is 0.32810983061790466
# The 733 batch, training loss is 0.14725248515605927
# The 734 batch, training loss is 0.12089896947145462
# The 735 batch, training loss is 0.09777257591485977
# The 736 batch, training loss is 0.12171773612499237
# The 737 batch, training loss is 0.1537550985813141
# The 738 batch, training loss is 0.21627283096313477
# The 739 batch, training loss is 0.2842668890953064
# The 740 batch, training loss is 0.2633383870124817
# The 741 batch, training loss is 0.21919623017311096
# The 742 batch, training loss is 0.17668285965919495
# The 743 batch, training loss is 0.1925957202911377
# The 744 batch, training loss is 0.21860231459140778
# The 745 batch, training loss is 0.2402956634759903
# The 746 batch, training loss is 0.1880827099084854
# The 747 batch, training loss is 0.12560081481933594
# The 748 batch, training loss is 0.1949167400598526
# The 749 batch, training loss is 0.12853676080703735
# The 750 batch, training loss is 0.15433518588542938
# The 751 batch, training loss is 0.09214675426483154
# The 752 batch, training loss is 0.23676611483097076
# The 753 batch, training loss is 0.13218756020069122
# The 754 batch, training loss is 0.11978606134653091
# The 755 batch, training loss is 0.19646263122558594
# The 756 batch, training loss is 0.15201649069786072
# The 757 batch, training loss is 0.1201886534690857
# The 758 batch, training loss is 0.19857357442378998
# The 759 batch, training loss is 0.29027706384658813
# The 760 batch, training loss is 0.15862548351287842
# The 761 batch, training loss is 0.24898749589920044
# The 762 batch, training loss is 0.18277648091316223
# The 763 batch, training loss is 0.07405318319797516
# The 764 batch, training loss is 0.27285921573638916
# The 765 batch, training loss is 0.09409428387880325
# The 766 batch, training loss is 0.26605844497680664
# The 767 batch, training loss is 0.24483676254749298
# The 768 batch, training loss is 0.09130605310201645
# The 769 batch, training loss is 0.10159196704626083
# The 770 batch, training loss is 0.13867218792438507
# The 771 batch, training loss is 0.1143341213464737
# The 772 batch, training loss is 0.13840265572071075
# The 773 batch, training loss is 0.23533715307712555
# The 774 batch, training loss is 0.15109547972679138
# The 775 batch, training loss is 0.12162331491708755
# The 776 batch, training loss is 0.13830067217350006
# The 777 batch, training loss is 0.11358912289142609
# The 778 batch, training loss is 0.11605572700500488
# The 779 batch, training loss is 0.17813706398010254
# The 780 batch, training loss is 0.28104472160339355
# The 781 batch, training loss is 0.16627196967601776
# The 782 batch, training loss is 0.14584338665008545
# The 783 batch, training loss is 0.18317964673042297
# The 784 batch, training loss is 0.10972736775875092
# The 785 batch, training loss is 0.11384741961956024
# The 786 batch, training loss is 0.2637702524662018
# The 787 batch, training loss is 0.28436633944511414
# The 788 batch, training loss is 0.08359041064977646
# The 789 batch, training loss is 0.1706589162349701
# The 790 batch, training loss is 0.1437685787677765
# The 791 batch, training loss is 0.23725253343582153
# The 792 batch, training loss is 0.08741821348667145
# The 793 batch, training loss is 0.08515092730522156
# The 794 batch, training loss is 0.41887587308883667
# The 795 batch, training loss is 0.14054955542087555
# The 796 batch, training loss is 0.13130305707454681
# The 797 batch, training loss is 0.3281242251396179
# The 798 batch, training loss is 0.1617256999015808
# The 799 batch, training loss is 0.18371139466762543
# The 800 batch, training loss is 0.24695272743701935
# The 801 batch, training loss is 0.16994419693946838
# The 802 batch, training loss is 0.2290920615196228
# The 803 batch, training loss is 0.20751245319843292
# The 804 batch, training loss is 0.14864186942577362
# The 805 batch, training loss is 0.14771048724651337
# The 806 batch, training loss is 0.12412054091691971
# The 807 batch, training loss is 0.14318594336509705
# The 808 batch, training loss is 0.12851862609386444
# The 809 batch, training loss is 0.31424057483673096
# The 810 batch, training loss is 0.2080695927143097
# The 811 batch, training loss is 0.08424241840839386
# The 812 batch, training loss is 0.10856455564498901
# The 813 batch, training loss is 0.16574527323246002
# The 814 batch, training loss is 0.07608965039253235
# The 815 batch, training loss is 0.08887282013893127
# The 816 batch, training loss is 0.31809258460998535
# The 817 batch, training loss is 0.06639833003282547
# The 818 batch, training loss is 0.22076654434204102
# The 819 batch, training loss is 0.23284348845481873
# The 820 batch, training loss is 0.1409732550382614
# The 821 batch, training loss is 0.1367352306842804
# The 822 batch, training loss is 0.07767535001039505
# The 823 batch, training loss is 0.07434303313493729
# The 824 batch, training loss is 0.19581815600395203
# The 825 batch, training loss is 0.342693954706192
# The 826 batch, training loss is 0.11806463450193405
# The 827 batch, training loss is 0.057036951184272766
# The 828 batch, training loss is 0.20917163789272308
# The 829 batch, training loss is 0.14745165407657623
# The 830 batch, training loss is 0.18606555461883545
# The 831 batch, training loss is 0.19065195322036743
# The 832 batch, training loss is 0.21453909575939178
# The 833 batch, training loss is 0.06207311898469925
# The 834 batch, training loss is 0.2456434667110443
# The 835 batch, training loss is 0.09447634220123291
# The 836 batch, training loss is 0.1412811428308487
# The 837 batch, training loss is 0.041808001697063446
# The 838 batch, training loss is 0.09918716549873352
# The 839 batch, training loss is 0.1743832528591156
# The 840 batch, training loss is 0.10179796069860458
# The 841 batch, training loss is 0.052643872797489166
# The 842 batch, training loss is 0.11148405820131302
# The 843 batch, training loss is 0.1386958509683609
# The 844 batch, training loss is 0.11120660603046417
# The 845 batch, training loss is 0.05989411473274231
# The 846 batch, training loss is 0.13030490279197693
# The 847 batch, training loss is 0.0541904978454113
# The 848 batch, training loss is 0.11750474572181702
# The 849 batch, training loss is 0.08435654640197754
# The 850 batch, training loss is 0.08867432177066803
# The 851 batch, training loss is 0.1513272076845169
# The 852 batch, training loss is 0.1210194006562233
# The 853 batch, training loss is 0.2904481291770935
# The 854 batch, training loss is 0.26354217529296875
# The 855 batch, training loss is 0.093377485871315
# The 856 batch, training loss is 0.22518527507781982
# The 857 batch, training loss is 0.0889883041381836
# The 858 batch, training loss is 0.12983739376068115
# The 859 batch, training loss is 0.15422740578651428
# The 860 batch, training loss is 0.25044336915016174
# The 861 batch, training loss is 0.1560840755701065
# The 862 batch, training loss is 0.27694177627563477
# The 863 batch, training loss is 0.11385529488325119
# The 864 batch, training loss is 0.05519041046500206
# The 865 batch, training loss is 0.10173619538545609
# The 866 batch, training loss is 0.27249157428741455
# The 867 batch, training loss is 0.17012806236743927
# The 868 batch, training loss is 0.1307293027639389
# The 869 batch, training loss is 0.14611518383026123
# The 870 batch, training loss is 0.21969935297966003
# The 871 batch, training loss is 0.08532705903053284
# The 872 batch, training loss is 0.08105183392763138
# The 873 batch, training loss is 0.21144644916057587
# The 874 batch, training loss is 0.1800166815519333
# The 875 batch, training loss is 0.14270903170108795
# The 876 batch, training loss is 0.1751345992088318
# The 877 batch, training loss is 0.08570532500743866
# The 878 batch, training loss is 0.05997197702527046
# The 879 batch, training loss is 0.29953643679618835
# The 880 batch, training loss is 0.06444569677114487
# The 881 batch, training loss is 0.2061704397201538
# The 882 batch, training loss is 0.14953528344631195
# The 883 batch, training loss is 0.16314847767353058
# The 884 batch, training loss is 0.20102080702781677
# The 885 batch, training loss is 0.05276530608534813
# The 886 batch, training loss is 0.11380995810031891
# The 887 batch, training loss is 0.391401082277298
# The 888 batch, training loss is 0.0995350331068039
# The 889 batch, training loss is 0.1193237379193306
# The 890 batch, training loss is 0.1507413536310196
# The 891 batch, training loss is 0.21500836312770844
# The 892 batch, training loss is 0.10313873738050461
# The 893 batch, training loss is 0.20718792080879211
# The 894 batch, training loss is 0.10018978267908096
# The 895 batch, training loss is 0.20206764340400696
# The 896 batch, training loss is 0.22039473056793213
# The 897 batch, training loss is 0.12770584225654602
# The 898 batch, training loss is 0.09056112915277481
# The 899 batch, training loss is 0.21063221991062164
# The 900 batch, training loss is 0.12860436737537384
# The 901 batch, training loss is 0.20285561680793762
# The 902 batch, training loss is 0.21988913416862488
# The 903 batch, training loss is 0.13171075284481049
# The 904 batch, training loss is 0.07474806159734726
# The 905 batch, training loss is 0.23396597802639008
# The 906 batch, training loss is 0.07916565984487534
# The 907 batch, training loss is 0.1517072468996048
# The 908 batch, training loss is 0.20726600289344788
# The 909 batch, training loss is 0.16367998719215393
# The 910 batch, training loss is 0.24234479665756226
# The 911 batch, training loss is 0.08369115740060806
# The 912 batch, training loss is 0.10275139659643173
# The 913 batch, training loss is 0.12243035435676575
# The 914 batch, training loss is 0.18291249871253967
# The 915 batch, training loss is 0.10541819036006927
# The 916 batch, training loss is 0.15944431722164154
# The 917 batch, training loss is 0.1391848623752594
# The 918 batch, training loss is 0.06752025336027145
# The 919 batch, training loss is 0.0865245908498764
# The 920 batch, training loss is 0.2418936938047409
# The 921 batch, training loss is 0.12876293063163757
# The 922 batch, training loss is 0.13257013261318207
# The 923 batch, training loss is 0.1267327070236206
# The 924 batch, training loss is 0.1512024998664856
# The 925 batch, training loss is 0.21677730977535248
# The 926 batch, training loss is 0.18137133121490479
# The 927 batch, training loss is 0.34851109981536865
# The 928 batch, training loss is 0.0434921532869339
# The 929 batch, training loss is 0.20367901027202606
# The 930 batch, training loss is 0.13391853868961334
# The 931 batch, training loss is 0.20325210690498352
# The 932 batch, training loss is 0.24988901615142822
# The 933 batch, training loss is 0.1485496163368225
# The 934 batch, training loss is 0.04362110048532486
# The 935 batch, training loss is 0.1390504240989685
# The 936 batch, training loss is 0.11480362713336945
# The 0 batch, test loss is 0.16685856878757477
# The 1 batch, test loss is 0.06374303996562958
# The 2 batch, test loss is 0.10665585845708847
# The 3 batch, test loss is 0.18117722868919373
# The 4 batch, test loss is 0.0908699780702591
# The 5 batch, test loss is 0.2569160461425781
# The 6 batch, test loss is 0.16564902663230896
# The 7 batch, test loss is 0.18143896758556366
# The 8 batch, test loss is 0.16051684319972992
# The 9 batch, test loss is 0.18167051672935486
# The 10 batch, test loss is 0.16830545663833618
# The 11 batch, test loss is 0.21658973395824432
# The 12 batch, test loss is 0.03972272947430611
# The 13 batch, test loss is 0.15409095585346222
# The 14 batch, test loss is 0.22481302917003632
# The 15 batch, test loss is 0.23735392093658447
# The 16 batch, test loss is 0.13519853353500366
# The 17 batch, test loss is 0.11118942499160767
# The 18 batch, test loss is 0.23255237936973572
# The 19 batch, test loss is 0.34068840742111206
# The 20 batch, test loss is 0.2715371549129486
# The 21 batch, test loss is 0.18118374049663544
# The 22 batch, test loss is 0.1722700446844101
# The 23 batch, test loss is 0.2414337396621704
# The 24 batch, test loss is 0.20719288289546967
# The 25 batch, test loss is 0.2421194463968277
# The 26 batch, test loss is 0.27614226937294006
# The 27 batch, test loss is 0.333476722240448
# The 28 batch, test loss is 0.12320422381162643
# The 29 batch, test loss is 0.13832934200763702
# The 30 batch, test loss is 0.1485912799835205
# The 31 batch, test loss is 0.28029462695121765
# The 32 batch, test loss is 0.2343858927488327
# The 33 batch, test loss is 0.23277364671230316
# The 34 batch, test loss is 0.2476961612701416
# The 35 batch, test loss is 0.31317514181137085
# The 36 batch, test loss is 0.0703238919377327
# The 37 batch, test loss is 0.2950794994831085
# The 38 batch, test loss is 0.20426899194717407
# The 39 batch, test loss is 0.12062805891036987
# The 40 batch, test loss is 0.1989763379096985
# The 41 batch, test loss is 0.2024269998073578
# The 42 batch, test loss is 0.10286935418844223
# The 43 batch, test loss is 0.10466427356004715
# The 44 batch, test loss is 0.07566888630390167
# The 45 batch, test loss is 0.1660318821668625
# The 46 batch, test loss is 0.17149768769741058
# The 47 batch, test loss is 0.09863255172967911
# The 48 batch, test loss is 0.249544158577919
# The 49 batch, test loss is 0.08545008301734924
# The 50 batch, test loss is 0.09537774324417114
# The 51 batch, test loss is 0.09085139632225037
# The 52 batch, test loss is 0.1552048772573471
# The 53 batch, test loss is 0.06497086584568024
# The 54 batch, test loss is 0.14523223042488098
# The 55 batch, test loss is 0.2630746364593506
# The 56 batch, test loss is 0.17558246850967407
# The 57 batch, test loss is 0.07485179603099823
# The 58 batch, test loss is 0.220529243350029
# The 59 batch, test loss is 0.44934678077697754
# The 60 batch, test loss is 0.24460451304912567
# The 61 batch, test loss is 0.35274678468704224
# The 62 batch, test loss is 0.0987701341509819
# The 63 batch, test loss is 0.18997350335121155
# The 64 batch, test loss is 0.10680719465017319
# The 65 batch, test loss is 0.36186185479164124
# The 66 batch, test loss is 0.22881357371807098
# The 67 batch, test loss is 0.27726390957832336
# The 68 batch, test loss is 0.14143106341362
# The 69 batch, test loss is 0.14757993817329407
# The 70 batch, test loss is 0.19690047204494476
# The 71 batch, test loss is 0.20141547918319702
# The 72 batch, test loss is 0.17881493270397186
# The 73 batch, test loss is 0.07134168595075607
# The 74 batch, test loss is 0.12211668491363525
# The 75 batch, test loss is 0.22244763374328613
# The 76 batch, test loss is 0.24061588943004608
# The 77 batch, test loss is 0.22262299060821533
# The 78 batch, test loss is 0.08328934758901596
# The 79 batch, test loss is 0.12285330891609192
# The 80 batch, test loss is 0.13891051709651947
# The 81 batch, test loss is 0.0629250630736351
# The 82 batch, test loss is 0.07671812176704407
# The 83 batch, test loss is 0.07200801372528076
# The 84 batch, test loss is 0.03795298561453819
# The 85 batch, test loss is 0.028075098991394043
# The 86 batch, test loss is 0.04732559248805046
# The 87 batch, test loss is 0.05490382760763168
# The 88 batch, test loss is 0.21060478687286377
# The 89 batch, test loss is 0.19165891408920288
# The 90 batch, test loss is 0.02153277024626732
# The 91 batch, test loss is 0.06727547198534012
# The 92 batch, test loss is 0.12497960031032562
# The 93 batch, test loss is 0.3087916672229767
# The 94 batch, test loss is 0.22721225023269653
# The 95 batch, test loss is 0.13100671768188477
# The 96 batch, test loss is 0.2091260552406311
# The 97 batch, test loss is 0.010647986084222794
# The 98 batch, test loss is 0.009977503679692745
# The 99 batch, test loss is 0.05774412304162979
# The 100 batch, test loss is 0.08207032084465027
# The 101 batch, test loss is 0.12614966928958893
# The 102 batch, test loss is 0.21781598031520844
# The 103 batch, test loss is 0.3297402858734131
# The 104 batch, test loss is 0.023121071979403496
# The 105 batch, test loss is 0.17700862884521484
# The 106 batch, test loss is 0.12985947728157043
# The 107 batch, test loss is 0.06498804688453674
# The 108 batch, test loss is 0.04902688413858414
# The 109 batch, test loss is 0.027792608365416527
# The 110 batch, test loss is 0.07188941538333893
# The 111 batch, test loss is 0.05927060917019844
# The 112 batch, test loss is 0.056224144995212555
# The 113 batch, test loss is 0.041652943938970566
# The 114 batch, test loss is 0.02204529382288456
# The 115 batch, test loss is 0.018762759864330292
# The 116 batch, test loss is 0.14037851989269257
# The 117 batch, test loss is 0.10124292969703674
# The 118 batch, test loss is 0.03913338854908943
# The 119 batch, test loss is 0.051572516560554504
# The 120 batch, test loss is 0.047012440860271454
# The 121 batch, test loss is 0.07677194476127625
# The 122 batch, test loss is 0.14391928911209106
# The 123 batch, test loss is 0.23431919515132904
# The 124 batch, test loss is 0.09319566935300827
# The 125 batch, test loss is 0.10423257946968079
# The 126 batch, test loss is 0.1872812807559967
# The 127 batch, test loss is 0.03450090438127518
# The 128 batch, test loss is 0.09454289823770523
# The 129 batch, test loss is 0.1675197184085846
# The 130 batch, test loss is 0.08581922948360443
# The 131 batch, test loss is 0.09798932820558548
# The 132 batch, test loss is 0.043603356927633286
# The 133 batch, test loss is 0.06475740671157837
# The 134 batch, test loss is 0.026074668392539024
# The 135 batch, test loss is 0.009996990673244
# The 136 batch, test loss is 0.006565512157976627
# The 137 batch, test loss is 0.006365422625094652
# The 138 batch, test loss is 0.01687386818230152
# The 139 batch, test loss is 0.011863368563354015
# The 140 batch, test loss is 0.17511728405952454
# The 141 batch, test loss is 0.13351429998874664
# The 142 batch, test loss is 0.025560447946190834
# The 143 batch, test loss is 0.05608236417174339
# The 144 batch, test loss is 0.04707053303718567
# The 145 batch, test loss is 0.041485708206892014
# The 146 batch, test loss is 0.026943329721689224
# The 147 batch, test loss is 0.061224695295095444
# The 148 batch, test loss is 0.06317543238401413
# The 149 batch, test loss is 0.08519589155912399
# The 150 batch, test loss is 0.18764637410640717
# The 151 batch, test loss is 0.31395718455314636
# The 152 batch, test loss is 0.4330821931362152
# The 153 batch, test loss is 0.23723220825195312
# The 154 batch, test loss is 0.29850688576698303
# The 155 batch, test loss is 0.22269849479198456
# The 156 batch, test loss is 0.027735551819205284
# The 5 model, test loss is 0.14434215965366382
# The 0 batch, training loss is 2.838244676589966
# The 1 batch, training loss is 2.513216972351074
# The 2 batch, training loss is 2.075852155685425
# The 3 batch, training loss is 2.1018476486206055
# The 4 batch, training loss is 1.8276327848434448
# The 5 batch, training loss is 1.7705552577972412
# The 6 batch, training loss is 1.635113000869751
# The 7 batch, training loss is 1.5671050548553467
# The 8 batch, training loss is 1.4926689863204956
# The 9 batch, training loss is 1.4254499673843384
# The 10 batch, training loss is 1.392848253250122
# The 11 batch, training loss is 1.0948389768600464
# The 12 batch, training loss is 1.1467421054840088
# The 13 batch, training loss is 1.2869224548339844
# The 14 batch, training loss is 0.8908863067626953
# The 15 batch, training loss is 1.037428617477417
# The 16 batch, training loss is 0.8549492359161377
# The 17 batch, training loss is 0.71040940284729
# The 18 batch, training loss is 0.9446897506713867
# The 19 batch, training loss is 0.7130534052848816
# The 20 batch, training loss is 0.8178901076316833
# The 21 batch, training loss is 0.669055700302124
# The 22 batch, training loss is 0.6541286706924438
# The 23 batch, training loss is 0.6183992028236389
# The 24 batch, training loss is 0.6623317003250122
# The 25 batch, training loss is 0.6044768691062927
# The 26 batch, training loss is 0.7268452048301697
# The 27 batch, training loss is 0.5532481074333191
# The 28 batch, training loss is 0.7059168219566345
# The 29 batch, training loss is 0.6659294366836548
# The 30 batch, training loss is 0.41495656967163086
# The 31 batch, training loss is 0.5055452585220337
# The 32 batch, training loss is 0.4761753976345062
# The 33 batch, training loss is 0.455647349357605
# The 34 batch, training loss is 0.5940460562705994
# The 35 batch, training loss is 0.5597867965698242
# The 36 batch, training loss is 0.38322314620018005
# The 37 batch, training loss is 0.49576669931411743
# The 38 batch, training loss is 0.4642076790332794
# The 39 batch, training loss is 0.6306066513061523
# The 40 batch, training loss is 0.47874149680137634
# The 41 batch, training loss is 0.5314306020736694
# The 42 batch, training loss is 0.41132715344429016
# The 43 batch, training loss is 0.3063761293888092
# The 44 batch, training loss is 0.5277270674705505
# The 45 batch, training loss is 0.6468666791915894
# The 46 batch, training loss is 0.42289263010025024
# The 47 batch, training loss is 0.4343169331550598
# The 48 batch, training loss is 0.1940617859363556
# The 49 batch, training loss is 0.3432316184043884
# The 50 batch, training loss is 0.3958558738231659
# The 51 batch, training loss is 0.5853368043899536
# The 52 batch, training loss is 0.4769652485847473
# The 53 batch, training loss is 0.257906973361969
# The 54 batch, training loss is 0.475859671831131
# The 55 batch, training loss is 0.42254623770713806
# The 56 batch, training loss is 0.5110755562782288
# The 57 batch, training loss is 0.6374914646148682
# The 58 batch, training loss is 0.4938097298145294
# The 59 batch, training loss is 0.5346771478652954
# The 60 batch, training loss is 0.3911167085170746
# The 61 batch, training loss is 0.4178639352321625
# The 62 batch, training loss is 0.2896755039691925
# The 63 batch, training loss is 0.4287349581718445
# The 64 batch, training loss is 0.28646597266197205
# The 65 batch, training loss is 0.3459699749946594
# The 66 batch, training loss is 0.3537551164627075
# The 67 batch, training loss is 0.22557620704174042
# The 68 batch, training loss is 0.4987456500530243
# The 69 batch, training loss is 0.5641980767250061
# The 70 batch, training loss is 0.414547324180603
# The 71 batch, training loss is 0.31959134340286255
# The 72 batch, training loss is 0.4512031078338623
# The 73 batch, training loss is 0.304633229970932
# The 74 batch, training loss is 0.4927818477153778
# The 75 batch, training loss is 0.4758562743663788
# The 76 batch, training loss is 0.5476709604263306
# The 77 batch, training loss is 0.28640100359916687
# The 78 batch, training loss is 0.1960238516330719
# The 79 batch, training loss is 0.29754242300987244
# The 80 batch, training loss is 0.6031200885772705
# The 81 batch, training loss is 0.305210143327713
# The 82 batch, training loss is 0.38398057222366333
# The 83 batch, training loss is 0.2849847376346588
# The 84 batch, training loss is 0.3302202522754669
# The 85 batch, training loss is 0.3765503466129303
# The 86 batch, training loss is 0.30997931957244873
# The 87 batch, training loss is 0.3109530508518219
# The 88 batch, training loss is 0.3050776422023773
# The 89 batch, training loss is 0.28155970573425293
# The 90 batch, training loss is 0.31431007385253906
# The 91 batch, training loss is 0.5789158940315247
# The 92 batch, training loss is 0.25475946068763733
# The 93 batch, training loss is 0.24483150243759155
# The 94 batch, training loss is 0.3066302239894867
# The 95 batch, training loss is 0.23180928826332092
# The 96 batch, training loss is 0.2780148386955261
# The 97 batch, training loss is 0.4226897358894348
# The 98 batch, training loss is 0.3285403847694397
# The 99 batch, training loss is 0.391722172498703
# The 100 batch, training loss is 0.29983386397361755
# The 101 batch, training loss is 0.4669232964515686
# The 102 batch, training loss is 0.3495088517665863
# The 103 batch, training loss is 0.33582741022109985
# The 104 batch, training loss is 0.49539437890052795
# The 105 batch, training loss is 0.4576505124568939
# The 106 batch, training loss is 0.32559409737586975
# The 107 batch, training loss is 0.37017881870269775
# The 108 batch, training loss is 0.20448963344097137
# The 109 batch, training loss is 0.3962854743003845
# The 110 batch, training loss is 0.29816073179244995
# The 111 batch, training loss is 0.3851175904273987
# The 112 batch, training loss is 0.2495894581079483
# The 113 batch, training loss is 0.28057488799095154
# The 114 batch, training loss is 0.36605286598205566
# The 115 batch, training loss is 0.3177416920661926
# The 116 batch, training loss is 0.3782498836517334
# The 117 batch, training loss is 0.29041650891304016
# The 118 batch, training loss is 0.531897783279419
# The 119 batch, training loss is 0.143580824136734
# The 120 batch, training loss is 0.2771896719932556
# The 121 batch, training loss is 0.3182905614376068
# The 122 batch, training loss is 0.4579322040081024
# The 123 batch, training loss is 0.2544260323047638
# The 124 batch, training loss is 0.21641044318675995
# The 125 batch, training loss is 0.34339919686317444
# The 126 batch, training loss is 0.4359026551246643
# The 127 batch, training loss is 0.4287303686141968
# The 128 batch, training loss is 0.2065189778804779
# The 129 batch, training loss is 0.4411448538303375
# The 130 batch, training loss is 0.3958074450492859
# The 131 batch, training loss is 0.22772906720638275
# The 132 batch, training loss is 0.27742183208465576
# The 133 batch, training loss is 0.21259644627571106
# The 134 batch, training loss is 0.3465266525745392
# The 135 batch, training loss is 0.28131261467933655
# The 136 batch, training loss is 0.35560786724090576
# The 137 batch, training loss is 0.35076314210891724
# The 138 batch, training loss is 0.24096274375915527
# The 139 batch, training loss is 0.34049192070961
# The 140 batch, training loss is 0.2372126430273056
# The 141 batch, training loss is 0.38857752084732056
# The 142 batch, training loss is 0.321412593126297
# The 143 batch, training loss is 0.5849964618682861
# The 144 batch, training loss is 0.2518117129802704
# The 145 batch, training loss is 0.5338000655174255
# The 146 batch, training loss is 0.406620055437088
# The 147 batch, training loss is 0.30559879541397095
# The 148 batch, training loss is 0.2744951546192169
# The 149 batch, training loss is 0.39695292711257935
# The 150 batch, training loss is 0.2744225859642029
# The 151 batch, training loss is 0.2962822914123535
# The 152 batch, training loss is 0.2202821671962738
# The 153 batch, training loss is 0.2856755554676056
# The 154 batch, training loss is 0.17891860008239746
# The 155 batch, training loss is 0.2635456323623657
# The 156 batch, training loss is 0.2978159189224243
# The 157 batch, training loss is 0.19438716769218445
# The 158 batch, training loss is 0.35655269026756287
# The 159 batch, training loss is 0.21756182610988617
# The 160 batch, training loss is 0.29433995485305786
# The 161 batch, training loss is 0.3749270737171173
# The 162 batch, training loss is 0.1384793072938919
# The 163 batch, training loss is 0.2954327464103699
# The 164 batch, training loss is 0.25182420015335083
# The 165 batch, training loss is 0.14652660489082336
# The 166 batch, training loss is 0.37649548053741455
# The 167 batch, training loss is 0.26694318652153015
# The 168 batch, training loss is 0.22748741507530212
# The 169 batch, training loss is 0.2025669813156128
# The 170 batch, training loss is 0.2599245011806488
# The 171 batch, training loss is 0.3872109055519104
# The 172 batch, training loss is 0.265749990940094
# The 173 batch, training loss is 0.19001534581184387
# The 174 batch, training loss is 0.31446683406829834
# The 175 batch, training loss is 0.20881769061088562
# The 176 batch, training loss is 0.2261660248041153
# The 177 batch, training loss is 0.316024512052536
# The 178 batch, training loss is 0.16927093267440796
# The 179 batch, training loss is 0.3508204221725464
# The 180 batch, training loss is 0.3355565071105957
# The 181 batch, training loss is 0.15889611840248108
# The 182 batch, training loss is 0.26696452498435974
# The 183 batch, training loss is 0.2749800980091095
# The 184 batch, training loss is 0.18534605205059052
# The 185 batch, training loss is 0.26448509097099304
# The 186 batch, training loss is 0.16191573441028595
# The 187 batch, training loss is 0.3058295249938965
# The 188 batch, training loss is 0.20844267308712006
# The 189 batch, training loss is 0.3791162669658661
# The 190 batch, training loss is 0.2890094220638275
# The 191 batch, training loss is 0.6229010224342346
# The 192 batch, training loss is 0.15740369260311127
# The 193 batch, training loss is 0.45355284214019775
# The 194 batch, training loss is 0.23045192658901215
# The 195 batch, training loss is 0.1534879356622696
# The 196 batch, training loss is 0.26269832253456116
# The 197 batch, training loss is 0.27153480052948
# The 198 batch, training loss is 0.2887318730354309
# The 199 batch, training loss is 0.27118808031082153
# The 200 batch, training loss is 0.29200083017349243
# The 201 batch, training loss is 0.3217388391494751
# The 202 batch, training loss is 0.29221633076667786
# The 203 batch, training loss is 0.24477140605449677
# The 204 batch, training loss is 0.34684720635414124
# The 205 batch, training loss is 0.1972755789756775
# The 206 batch, training loss is 0.4447714686393738
# The 207 batch, training loss is 0.218186616897583
# The 208 batch, training loss is 0.2315473109483719
# The 209 batch, training loss is 0.23399920761585236
# The 210 batch, training loss is 0.22475802898406982
# The 211 batch, training loss is 0.18810448050498962
# The 212 batch, training loss is 0.2478940188884735
# The 213 batch, training loss is 0.2612760663032532
# The 214 batch, training loss is 0.20997262001037598
# The 215 batch, training loss is 0.1397363692522049
# The 216 batch, training loss is 0.3245699107646942
# The 217 batch, training loss is 0.4912615120410919
# The 218 batch, training loss is 0.25932830572128296
# The 219 batch, training loss is 0.19490893185138702
# The 220 batch, training loss is 0.2509409487247467
# The 221 batch, training loss is 0.10812005400657654
# The 222 batch, training loss is 0.13211676478385925
# The 223 batch, training loss is 0.2648690342903137
# The 224 batch, training loss is 0.22938182950019836
# The 225 batch, training loss is 0.4954645037651062
# The 226 batch, training loss is 0.28725260496139526
# The 227 batch, training loss is 0.09731530398130417
# The 228 batch, training loss is 0.31847134232521057
# The 229 batch, training loss is 0.1886720061302185
# The 230 batch, training loss is 0.5017955899238586
# The 231 batch, training loss is 0.2306949496269226
# The 232 batch, training loss is 0.2872501313686371
# The 233 batch, training loss is 0.24785922467708588
# The 234 batch, training loss is 0.2758822739124298
# The 235 batch, training loss is 0.28845974802970886
# The 236 batch, training loss is 0.14282077550888062
# The 237 batch, training loss is 0.15967746078968048
# The 238 batch, training loss is 0.11676478385925293
# The 239 batch, training loss is 0.5046700835227966
# The 240 batch, training loss is 0.3433838486671448
# The 241 batch, training loss is 0.3305748999118805
# The 242 batch, training loss is 0.1435653269290924
# The 243 batch, training loss is 0.2595536410808563
# The 244 batch, training loss is 0.21891023218631744
# The 245 batch, training loss is 0.23159831762313843
# The 246 batch, training loss is 0.23082959651947021
# The 247 batch, training loss is 0.34974798560142517
# The 248 batch, training loss is 0.49198922514915466
# The 249 batch, training loss is 0.2118787318468094
# The 250 batch, training loss is 0.1491394340991974
# The 251 batch, training loss is 0.20572581887245178
# The 252 batch, training loss is 0.1580127328634262
# The 253 batch, training loss is 0.15323109924793243
# The 254 batch, training loss is 0.11235639452934265
# The 255 batch, training loss is 0.12055099755525589
# The 256 batch, training loss is 0.13670827448368073
# The 257 batch, training loss is 0.302095890045166
# The 258 batch, training loss is 0.35056522488594055
# The 259 batch, training loss is 0.266490638256073
# The 260 batch, training loss is 0.17231741547584534
# The 261 batch, training loss is 0.1012415736913681
# The 262 batch, training loss is 0.20294560492038727
# The 263 batch, training loss is 0.18549053370952606
# The 264 batch, training loss is 0.322236031293869
# The 265 batch, training loss is 0.08768228441476822
# The 266 batch, training loss is 0.16044460237026215
# The 267 batch, training loss is 0.13284407556056976
# The 268 batch, training loss is 0.280161589384079
# The 269 batch, training loss is 0.09602906554937363
# The 270 batch, training loss is 0.12644298374652863
# The 271 batch, training loss is 0.1973559409379959
# The 272 batch, training loss is 0.1690731793642044
# The 273 batch, training loss is 0.2531077265739441
# The 274 batch, training loss is 0.4320257604122162
# The 275 batch, training loss is 0.26476389169692993
# The 276 batch, training loss is 0.30839622020721436
# The 277 batch, training loss is 0.23483005166053772
# The 278 batch, training loss is 0.1257191002368927
# The 279 batch, training loss is 0.13172569870948792
# The 280 batch, training loss is 0.08737082779407501
# The 281 batch, training loss is 0.2342461496591568
# The 282 batch, training loss is 0.27751365303993225
# The 283 batch, training loss is 0.07122167199850082
# The 284 batch, training loss is 0.0861489400267601
# The 285 batch, training loss is 0.20149865746498108
# The 286 batch, training loss is 0.1237509697675705
# The 287 batch, training loss is 0.19057056307792664
# The 288 batch, training loss is 0.22916914522647858
# The 289 batch, training loss is 0.19345539808273315
# The 290 batch, training loss is 0.2745416760444641
# The 291 batch, training loss is 0.37699273228645325
# The 292 batch, training loss is 0.3370295464992523
# The 293 batch, training loss is 0.14676231145858765
# The 294 batch, training loss is 0.30233868956565857
# The 295 batch, training loss is 0.19490282237529755
# The 296 batch, training loss is 0.11669158935546875
# The 297 batch, training loss is 0.20961806178092957
# The 298 batch, training loss is 0.3352074921131134
# The 299 batch, training loss is 0.2739066183567047
# The 300 batch, training loss is 0.1293431967496872
# The 301 batch, training loss is 0.12518514692783356
# The 302 batch, training loss is 0.266683965921402
# The 303 batch, training loss is 0.23038825392723083
# The 304 batch, training loss is 0.11731403321027756
# The 305 batch, training loss is 0.09179519861936569
# The 306 batch, training loss is 0.26729318499565125
# The 307 batch, training loss is 0.23185475170612335
# The 308 batch, training loss is 0.22879865765571594
# The 309 batch, training loss is 0.23393529653549194
# The 310 batch, training loss is 0.11566516011953354
# The 311 batch, training loss is 0.31679999828338623
# The 312 batch, training loss is 0.2367425262928009
# The 313 batch, training loss is 0.13150694966316223
# The 314 batch, training loss is 0.23430079221725464
# The 315 batch, training loss is 0.1651819348335266
# The 316 batch, training loss is 0.10142751038074493
# The 317 batch, training loss is 0.12223318219184875
# The 318 batch, training loss is 0.33607539534568787
# The 319 batch, training loss is 0.16272173821926117
# The 320 batch, training loss is 0.14633020758628845
# The 321 batch, training loss is 0.18260960280895233
# The 322 batch, training loss is 0.2482396364212036
# The 323 batch, training loss is 0.20763230323791504
# The 324 batch, training loss is 0.24844244122505188
# ...
# The 773 batch, training loss is 0.12055420875549316
# The 774 batch, training loss is 0.10495969653129578
# The 775 batch, training loss is 0.07882007956504822
# The 776 batch, training loss is 0.10135574638843536
# The 777 batch, training loss is 0.28775134682655334
# The 778 batch, training loss is 0.2577432096004486
# The 779 batch, training loss is 0.19115428626537323
# The 780 batch, training loss is 0.15037262439727783
# The 781 batch, training loss is 0.15396058559417725
# The 782 batch, training loss is 0.14839084446430206
# The 783 batch, training loss is 0.0882268100976944
# The 784 batch, training loss is 0.06226571649312973
# The 785 batch, training loss is 0.19293105602264404
# The 786 batch, training loss is 0.22370710968971252
# The 787 batch, training loss is 0.1769886165857315
# The 788 batch, training loss is 0.09470067173242569
# The 789 batch, training loss is 0.14530901610851288
# The 790 batch, training loss is 0.19103626906871796
# The 791 batch, training loss is 0.21119056642055511
# The 792 batch, training loss is 0.17108875513076782
# The 793 batch, training loss is 0.09203962236642838
# The 794 batch, training loss is 0.20988184213638306
# The 795 batch, training loss is 0.044162482023239136
# The 796 batch, training loss is 0.08974617719650269
# The 797 batch, training loss is 0.12205887585878372
# The 798 batch, training loss is 0.16965101659297943
# The 799 batch, training loss is 0.2526964843273163
# The 800 batch, training loss is 0.10182897746562958
# The 801 batch, training loss is 0.041410692036151886
# The 802 batch, training loss is 0.25959137082099915
# The 803 batch, training loss is 0.05596966668963432
# The 804 batch, training loss is 0.14631465077400208
# The 805 batch, training loss is 0.19459772109985352
# The 806 batch, training loss is 0.1790674477815628
# The 807 batch, training loss is 0.18128308653831482
# The 808 batch, training loss is 0.1450791209936142
# The 809 batch, training loss is 0.06242605671286583
# The 810 batch, training loss is 0.14923982322216034
# The 811 batch, training loss is 0.13587398827075958
# The 812 batch, training loss is 0.1500844955444336
# The 813 batch, training loss is 0.1266883909702301
# The 814 batch, training loss is 0.2851713001728058
# The 815 batch, training loss is 0.10523990541696548
# The 816 batch, training loss is 0.13745534420013428
# The 817 batch, training loss is 0.046057652682065964
# The 818 batch, training loss is 0.020194562152028084
# The 819 batch, training loss is 0.14548423886299133
# The 820 batch, training loss is 0.03807957097887993
# The 821 batch, training loss is 0.19586965441703796
# The 822 batch, training loss is 0.06343314796686172
# The 823 batch, training loss is 0.18007229268550873
# The 824 batch, training loss is 0.19218963384628296
# The 825 batch, training loss is 0.04822652414441109
# The 826 batch, training loss is 0.1513536423444748
# The 827 batch, training loss is 0.04769877344369888
# The 828 batch, training loss is 0.08333947509527206
# The 829 batch, training loss is 0.04341234266757965
# The 830 batch, training loss is 0.10677559673786163
# The 831 batch, training loss is 0.043805286288261414
# The 832 batch, training loss is 0.015834756195545197
# The 833 batch, training loss is 0.4680308997631073
# The 834 batch, training loss is 0.06890945136547089
# The 835 batch, training loss is 0.03861262649297714
# The 836 batch, training loss is 0.0739106833934784
# The 837 batch, training loss is 0.086138516664505
# The 838 batch, training loss is 0.12129382789134979
# The 839 batch, training loss is 0.03967222571372986
# The 840 batch, training loss is 0.13247063755989075
# The 841 batch, training loss is 0.10904539376497269
# The 842 batch, training loss is 0.10131620615720749
# The 843 batch, training loss is 0.42771026492118835
# The 844 batch, training loss is 0.12221810221672058
# The 845 batch, training loss is 0.1920286864042282
# The 846 batch, training loss is 0.10673244297504425
# The 847 batch, training loss is 0.11010138690471649
# The 848 batch, training loss is 0.12000799924135208
# The 849 batch, training loss is 0.1772935837507248
# The 850 batch, training loss is 0.25496840476989746
# The 851 batch, training loss is 0.11280249059200287
# The 852 batch, training loss is 0.038380563259124756
# The 853 batch, training loss is 0.20195713639259338
# The 854 batch, training loss is 0.08550380915403366
# The 855 batch, training loss is 0.13915900886058807
# The 856 batch, training loss is 0.03876515477895737
# The 857 batch, training loss is 0.06501468271017075
# The 858 batch, training loss is 0.1485549360513687
# The 859 batch, training loss is 0.08430933952331543
# The 860 batch, training loss is 0.1399368792772293
# The 861 batch, training loss is 0.13023364543914795
# The 862 batch, training loss is 0.18058718740940094
# The 863 batch, training loss is 0.10411098599433899
# The 864 batch, training loss is 0.04723396897315979
# The 865 batch, training loss is 0.08377799391746521
# The 866 batch, training loss is 0.027263754978775978
# The 867 batch, training loss is 0.17823617160320282
# The 868 batch, training loss is 0.06494563817977905
# The 869 batch, training loss is 0.07570213824510574
# The 870 batch, training loss is 0.11654626578092575
# The 871 batch, training loss is 0.2695542871952057
# The 872 batch, training loss is 0.2383323311805725
# The 873 batch, training loss is 0.12201954424381256
# The 874 batch, training loss is 0.05942689999938011
# The 875 batch, training loss is 0.3117821216583252
# The 876 batch, training loss is 0.1117795780301094
# The 877 batch, training loss is 0.13019336760044098
# The 878 batch, training loss is 0.251487135887146
# The 879 batch, training loss is 0.12827004492282867
# The 880 batch, training loss is 0.03589813411235809
# The 881 batch, training loss is 0.17529116570949554
# The 882 batch, training loss is 0.26805007457733154
# The 883 batch, training loss is 0.10095727443695068
# The 884 batch, training loss is 0.04939214885234833
# The 885 batch, training loss is 0.07232928276062012
# The 886 batch, training loss is 0.074956975877285
# The 887 batch, training loss is 0.10488025099039078
# The 888 batch, training loss is 0.1520029604434967
# The 889 batch, training loss is 0.08477859199047089
# The 890 batch, training loss is 0.06431266665458679
# The 891 batch, training loss is 0.08248618990182877
# The 892 batch, training loss is 0.11711256206035614
# The 893 batch, training loss is 0.22398695349693298
# The 894 batch, training loss is 0.05909888073801994
# The 895 batch, training loss is 0.2897443175315857
# The 896 batch, training loss is 0.03301772102713585
# The 897 batch, training loss is 0.32190027832984924
# The 898 batch, training loss is 0.21394094824790955
# The 899 batch, training loss is 0.2687903642654419
# The 900 batch, training loss is 0.2533782720565796
# The 901 batch, training loss is 0.14985983073711395
# The 902 batch, training loss is 0.13411249220371246
# The 903 batch, training loss is 0.06930489838123322
# The 904 batch, training loss is 0.1816173642873764
# The 905 batch, training loss is 0.08934443444013596
# The 906 batch, training loss is 0.09985122084617615
# The 907 batch, training loss is 0.08264995366334915
# The 908 batch, training loss is 0.11191152781248093
# The 909 batch, training loss is 0.10524258762598038
# The 910 batch, training loss is 0.14331381022930145
# The 911 batch, training loss is 0.07380732148885727
# The 912 batch, training loss is 0.06738842278718948
# The 913 batch, training loss is 0.02561805211007595
# The 914 batch, training loss is 0.09354086220264435
# The 915 batch, training loss is 0.12459960579872131
# The 916 batch, training loss is 0.0925738662481308
# The 917 batch, training loss is 0.1123824194073677
# The 918 batch, training loss is 0.024292856454849243
# The 919 batch, training loss is 0.05479171872138977
# The 920 batch, training loss is 0.07103326916694641
# The 921 batch, training loss is 0.03123297542333603
# The 922 batch, training loss is 0.1772134155035019
# The 923 batch, training loss is 0.2819638252258301
# The 924 batch, training loss is 0.13970544934272766
# The 925 batch, training loss is 0.09825387597084045
# The 926 batch, training loss is 0.16457180678844452
# The 927 batch, training loss is 0.10309111326932907
# The 928 batch, training loss is 0.10763350874185562
# The 929 batch, training loss is 0.10189998894929886
# The 930 batch, training loss is 0.09540299326181412
# The 931 batch, training loss is 0.14052805304527283
# The 932 batch, training loss is 0.1310683637857437
# The 933 batch, training loss is 0.017552128061652184
# The 934 batch, training loss is 0.08994204550981522
# The 935 batch, training loss is 0.07018160074949265
# The 936 batch, training loss is 0.11464567482471466
# The 0 batch, test loss is 0.03551030904054642
# The 1 batch, test loss is 0.05730201303958893
# The 2 batch, test loss is 0.06457947194576263
# The 3 batch, test loss is 0.11837495118379593
# The 4 batch, test loss is 0.09292356669902802
# The 5 batch, test loss is 0.14815819263458252
# The 6 batch, test loss is 0.052140310406684875
# The 7 batch, test loss is 0.13317394256591797
# The 8 batch, test loss is 0.123773954808712
# The 9 batch, test loss is 0.2008732259273529
# The 10 batch, test loss is 0.19623973965644836
# The 11 batch, test loss is 0.15595082938671112
# The 12 batch, test loss is 0.054540980607271194
# The 13 batch, test loss is 0.12332980334758759
# The 14 batch, test loss is 0.1983862966299057
# The 15 batch, test loss is 0.17590871453285217
# The 16 batch, test loss is 0.08275345712900162
# The 17 batch, test loss is 0.10557395964860916
# The 18 batch, test loss is 0.1552717685699463
# The 19 batch, test loss is 0.41285908222198486
# The 20 batch, test loss is 0.23710179328918457
# The 21 batch, test loss is 0.09577745199203491
# The 22 batch, test loss is 0.10594852268695831
# The 23 batch, test loss is 0.3084454834461212
# The 24 batch, test loss is 0.20691929757595062
# The 25 batch, test loss is 0.16731853783130646
# The 26 batch, test loss is 0.18217605352401733
# The 27 batch, test loss is 0.25827884674072266
# The 28 batch, test loss is 0.09132041782140732
# The 29 batch, test loss is 0.15634876489639282
# The 30 batch, test loss is 0.17099010944366455
# The 31 batch, test loss is 0.29010552167892456
# The 32 batch, test loss is 0.23505853116512299
# The 33 batch, test loss is 0.14444184303283691
# The 34 batch, test loss is 0.17302460968494415
# The 35 batch, test loss is 0.25371742248535156
# The 36 batch, test loss is 0.03904947638511658
# The 37 batch, test loss is 0.21879152953624725
# The 38 batch, test loss is 0.141013041138649
# The 39 batch, test loss is 0.07539086788892746
# The 40 batch, test loss is 0.1446228325366974
# The 41 batch, test loss is 0.11063867062330246
# The 42 batch, test loss is 0.08533622324466705
# The 43 batch, test loss is 0.10023757070302963
# The 44 batch, test loss is 0.05633723363280296
# The 45 batch, test loss is 0.2118971347808838
# The 46 batch, test loss is 0.12379592657089233
# The 47 batch, test loss is 0.06602794677019119
# The 48 batch, test loss is 0.21068112552165985
# The 49 batch, test loss is 0.03877139836549759
# The 50 batch, test loss is 0.12069782614707947
# The 51 batch, test loss is 0.058058083057403564
# The 52 batch, test loss is 0.08125273883342743
# The 53 batch, test loss is 0.0417577289044857
# The 54 batch, test loss is 0.057622477412223816
# The 55 batch, test loss is 0.2602064609527588
# The 56 batch, test loss is 0.20911704003810883
# The 57 batch, test loss is 0.08573315292596817
# The 58 batch, test loss is 0.27145296335220337
# The 59 batch, test loss is 0.3125859200954437
# The 60 batch, test loss is 0.2224930226802826
# The 61 batch, test loss is 0.2861042320728302
# The 62 batch, test loss is 0.14454619586467743
# The 63 batch, test loss is 0.26472151279449463
# The 64 batch, test loss is 0.0964059978723526
# The 65 batch, test loss is 0.19390051066875458
# The 66 batch, test loss is 0.18144944310188293
# The 67 batch, test loss is 0.13923712074756622
# The 68 batch, test loss is 0.10121332854032516
# The 69 batch, test loss is 0.09163884818553925
# The 70 batch, test loss is 0.13509921729564667
# The 71 batch, test loss is 0.1464875191450119
# The 72 batch, test loss is 0.16685809195041656
# The 73 batch, test loss is 0.07486531138420105
# The 74 batch, test loss is 0.1192808523774147
# The 75 batch, test loss is 0.20323306322097778
# The 76 batch, test loss is 0.23758310079574585
# The 77 batch, test loss is 0.24238131940364838
# The 78 batch, test loss is 0.07416995614767075
# The 79 batch, test loss is 0.11962680518627167
# The 80 batch, test loss is 0.15146860480308533
# The 81 batch, test loss is 0.0606585331261158
# The 82 batch, test loss is 0.013799618929624557
# The 83 batch, test loss is 0.15375439822673798
# The 84 batch, test loss is 0.005753143224865198
# The 85 batch, test loss is 0.06360403448343277
# The 86 batch, test loss is 0.02557142823934555
# The 87 batch, test loss is 0.09990119189023972
# The 88 batch, test loss is 0.23532655835151672
# The 89 batch, test loss is 0.1703825294971466
# The 90 batch, test loss is 0.008874702267348766
# The 91 batch, test loss is 0.10268425196409225
# The 92 batch, test loss is 0.1248084083199501
# The 93 batch, test loss is 0.20388619601726532
# The 94 batch, test loss is 0.11948022246360779
# The 95 batch, test loss is 0.044796086847782135
# The 96 batch, test loss is 0.09053798764944077
# The 97 batch, test loss is 0.0039241318590939045
# The 98 batch, test loss is 0.0010375503916293383
# The 99 batch, test loss is 0.020649796351790428
# The 100 batch, test loss is 0.06689070165157318
# The 101 batch, test loss is 0.0646098181605339
# The 102 batch, test loss is 0.18844987452030182
# The 103 batch, test loss is 0.3284137547016144
# The 104 batch, test loss is 0.008673455566167831
# The 105 batch, test loss is 0.10156706720590591
# The 106 batch, test loss is 0.03314342349767685
# The 107 batch, test loss is 0.019703125581145287
# The 108 batch, test loss is 0.007021353114396334
# The 109 batch, test loss is 0.014668039046227932
# The 110 batch, test loss is 0.046949442476034164
# The 111 batch, test loss is 0.013813188299536705
# The 112 batch, test loss is 0.07475721836090088
# The 113 batch, test loss is 0.022867226973176003
# The 114 batch, test loss is 0.005914582405239344
# The 115 batch, test loss is 0.005099445581436157
# The 116 batch, test loss is 0.1148582398891449
# The 117 batch, test loss is 0.06484904885292053
# The 118 batch, test loss is 0.0382545031607151
# The 119 batch, test loss is 0.01387951709330082
# The 120 batch, test loss is 0.01643826626241207
# The 121 batch, test loss is 0.01954648271203041
# The 122 batch, test loss is 0.13953736424446106
# The 123 batch, test loss is 0.2272433340549469
# The 124 batch, test loss is 0.07890323549509048
# The 125 batch, test loss is 0.11269362270832062
# The 126 batch, test loss is 0.08841860294342041
# The 127 batch, test loss is 0.022123122587800026
# The 128 batch, test loss is 0.016921645030379295
# The 129 batch, test loss is 0.06251557171344757
# The 130 batch, test loss is 0.10839825123548508
# The 131 batch, test loss is 0.04303475096821785
# The 132 batch, test loss is 0.028883328661322594
# The 133 batch, test loss is 0.12337528169155121
# The 134 batch, test loss is 0.007011215668171644
# The 135 batch, test loss is 0.0016592505853623152
# The 136 batch, test loss is 0.010514326393604279
# The 137 batch, test loss is 0.0016151336021721363
# The 138 batch, test loss is 0.005101562011986971
# The 139 batch, test loss is 0.006602423265576363
# The 140 batch, test loss is 0.3422068953514099
# The 141 batch, test loss is 0.18065956234931946
# The 142 batch, test loss is 0.009700795635581017
# The 143 batch, test loss is 0.011664698831737041
# The 144 batch, test loss is 0.006177786272019148
# The 145 batch, test loss is 0.085301473736763
# The 146 batch, test loss is 0.016064001247286797
# The 147 batch, test loss is 0.011752013117074966
# The 148 batch, test loss is 0.0346834622323513
# The 149 batch, test loss is 0.10272766649723053
# The 150 batch, test loss is 0.07122066617012024
# The 151 batch, test loss is 0.07600662112236023
# The 152 batch, test loss is 0.38394883275032043
# The 153 batch, test loss is 0.17252770066261292
# The 154 batch, test loss is 0.12416543811559677
# The 155 batch, test loss is 0.1288711577653885
# The 156 batch, test loss is 0.019383642822504044
# The 9 model, test loss is 0.11439395021457391

# %%
# Log scale, scaling behavior with model size
model_size = [8,11,16,23,32,45,64,91,128,181]
plt.plot(model_size, losses_2)
plt.xscale('log') # Adjusts the x-axis to a log scale
plt.yscale('log')
plt.title("training loss over time with different model size")
plt.xlabel('Model size (by number of filters in CNN)')
plt.ylabel('Test Loss')
plt.show()
